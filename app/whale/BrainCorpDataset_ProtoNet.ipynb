# %% [markdown]
# ### Imports

# %%
from dlcliche.image import *
sys.path.append('..') # app
sys.path.append('../..') # root
from easydict import EasyDict
from app_utils_clf import *
from whale_utils import *
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Sampler
import seaborn as sns

# %% [markdown]
# ### Parameters

# %%
args = EasyDict()
args.distance = 'l2'
args.n_train = 1
args.n_test = 1
args.q_train = 2
args.q_test = 5

args.k_train = 100
args.k_test = 34
SZ = 256
RE_SZ = 256

args.n_epochs = 100
args.drop_lr_every = 50
args.lr = 1e-4
args.init_weight = None

data_train = DATA_PATH
data_test  = DATA_PATH

args.checkpoint_monitor = 'categorical_accuracy'
args.checkpoint_period = 20

# %% [markdown]
# ### Dataset

# %%
DATA_PATH = '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/'

# %%
ref = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_img').glob('*/*.png'))]
aisle = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_38').glob('*/*.png'))]
# ref = aisle

proto_df = pd.DataFrame({'image_path' : [str(i) for i in ref], 'label' : [i.parent.name for i in ref]})
proto_df['type'] = 'reference'

le = LabelEncoder()
proto_df['label_id'] = le.fit_transform(proto_df.label)

proto_df.head()
# Out:
#                                           image_path     label       type  \
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  50038959  reference
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  53425502  reference
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  31184578  reference
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  53132214  reference
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  53050477  reference
#
#    label_id
# 0       515
# 1       818
# 2       276
# 3       762
# 4       715

# %%
query_df = pd.read_csv('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/img_to_labels.csv', index_col=0)

query_df.columns = ['image_path', 'label']

query_df['image_path'] = query_df.image_path.map(lambda x : '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/' + x)

item_mapping = {'1' : '54629736', '2' : '54481233', '3' : '3572171', '4' : '5558787', '5' : '4810550', '6' : '29566609', '7' : '100000000', '8':'4810554', '9' :'23296492','10':'22965966','11' :'100000010', '12' : '53798269', '13' : '100000001', '14':'5186005','15' :'23296489', '16':'38957303','17':'37989538', '18' :'5401467', '19' :'4385267', '20':'5142520','21':'53419173','22':'54747442','23':'53197162','24':'5262834','25':'54217299','26':'42430527','27':'6986914','28':'50563145','29':'100000003','30':'53564608','31':'100000004','32':'100000005','33':'100000006','34':'54271401','35':'100000007','36':'53621633','37':'53798262','38':'31525622','39':'53537941','40':'54739328','41':'52867343','42':'54003387','43':'54565142'}
remove_lst = ['junk', '1', '7', '13', '29', '31', '32', '33', '35', '11']

query_df = query_df[-query_df.label.isin(remove_lst)].reset_index(drop=True)

query_df['label'] = query_df.label.map(lambda x : item_mapping[x])

query_df['type'] = 'query'
query_df['label_id'] = le.transform(query_df.label.values)

query_df.drop_duplicates(inplace=True)
query_df.drop(query_df[query_df.image_path =='/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/SamsClub6235_031020_074323_818345_4.jpg'].index.values, axis=0, inplace=True)
query_df.reset_index(drop=True, inplace=True)
query_df.head()
# Out:
#                                           image_path    label   type  label_id
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410

# %%
# query_df = pd.read_csv('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/img_to_labels.csv', index_col=0)

# query_df.columns = ['image_path', 'label']

# query_df['image_path'] = query_df.image_path.map(lambda x : '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/' + x)

# item_mapping = {'1' : '54629736', '2' : '54481233', '3' : '3572171', '4' : '5558787', '5' : '4810550', '6' : '29566609', '7' : '100000000', '8':'4810554', '9' :'23296492','10':'22965966','11' :'100000010', '12' : '53798269', '13' : '100000001', '14':'5186005','15' :'23296489', '16':'38957303','17':'37989538', '18' :'5401467', '19' :'4385267', '20':'5142520','21':'53419173','22':'54747442','23':'53197162','24':'5262834','25':'54217299','26':'42430527','27':'6986914','28':'50563145','29':'100000003','30':'53564608','31':'100000004','32':'100000005','33':'100000006','34':'54271401','35':'100000007','36':'53621633','37':'53798262','38':'31525622','39':'53537941','40':'54739328','41':'52867343','42':'54003387','43':'54565142'}
# remove_lst = ['junk', '1', '7', '13', '29', '31', '32', '33', '35', '11']

# query_df = query_df[-query_df.label.isin(remove_lst)].reset_index(drop=True)

# query_df['label'] = query_df.label.map(lambda x : item_mapping[x])

# query_df['type'] = 'query'
# query_df['label_id'] = le.transform(query_df.label.values)

# query_df.drop_duplicates(inplace=True)
# query_df.drop(query_df[query_df.image_path =='/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/SamsClub6235_031020_074323_818345_4.jpg'].index.values, axis=0, inplace=True)
# query_df.reset_index(drop=True, inplace=True)
# query_df.head()
# Out:
#                                           image_path    label   type  label_id
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410

# %%
query_df.shape
# Out:
# (1671, 4)

# %%
refdf = proto_df.copy()
qdf = query_df.copy()
img_df = refdf[['image_path', 'label', 'type']].append(qdf[['image_path', 'label', 'type']], ignore_index=True)

# %%
le = LabelEncoder()
img_df['label_id'] = le.fit_transform(img_df.label)
img_df.head(), img_df.tail()
# Out:
# (                                          image_path     label       type  \
#  0  /home/raghava_balusu_walmartlabs_com/Work/ones...  50038959  reference
#  1  /home/raghava_balusu_walmartlabs_com/Work/ones...  53425502  reference
#  2  /home/raghava_balusu_walmartlabs_com/Work/ones...  31184578  reference
#  3  /home/raghava_balusu_walmartlabs_com/Work/ones...  53132214  reference
#  4  /home/raghava_balusu_walmartlabs_com/Work/ones...  53050477  reference
#
#     label_id
#  0       515
#  1       818
#  2       276
#  3       762
#  4       715  ,
#                                               image_path    label   type  \
#  3180  /home/raghava_balusu_walmartlabs_com/Work/ones...  4810554  query
#  3181  /home/raghava_balusu_walmartlabs_com/Work/ones...  4810554  query
#  3182  /home/raghava_balusu_walmartlabs_com/Work/ones...  4810554  query
#  3183  /home/raghava_balusu_walmartlabs_com/Work/ones...  4810554  query
#  3184  /home/raghava_balusu_walmartlabs_com/Work/ones...  4810554  query
#
#        label_id
#  3180       469
#  3181       469
#  3182       469
#  3183       469
#  3184       469  )

# %%
trn_qimgs = qdf.groupby('label').apply(lambda x: x[:5]).reset_index(drop=True).image_path.values
trn_qlabels = qdf[qdf.image_path.isin(trn_qimgs)].label.values

# %%
len(trn_qimgs)
# Out:
# 170

# %%
img_df['split'] = 'train'

# img_df.loc[img_df.label.isin(test_labels), 'split'] = 'valid'

# For including all ref images in training and query images in valid; Will ad reference images in valid later
img_df.loc[img_df.type == 'query', 'split'] = 'valid'
img_df.loc[(img_df.image_path.isin(trn_qimgs)) & (img_df.type == 'query'), 'split'] = 'train'

# %%
img_df.split.value_counts()
# Out:
# train    1684
# valid    1501
# Name: split, dtype: int64

# %%
trn_df = img_df[(img_df.split == 'train')]
temp = img_df[(img_df.type == 'reference') & (img_df.split == 'train') & -(img_df.label.isin(query_df.label.unique()))]
temp['type'] = 'query'
# trn_df = trn_df.append([temp for i in range(2)], ignore_index=True).reset_index(drop=True)
trn_df = trn_df.append([temp], ignore_index=True).reset_index(drop=True)

# %%
trn_df.shape, trn_df.type.value_counts()
# Out:
# ((3164, 5),
#  query        1650
#  reference    1514
#  Name: type, dtype: int64)

# %%
val_df = img_df[img_df.label.isin(query_df.label.unique())].reset_index(drop=True)

# Getting reference and query images in img_df in test_labels@7.8k 
# val_df = img_df[img_df.label.isin(test_labels)].reset_index(drop=True)

# %%
val_df.shape
# Out:
# (1705, 5)

# %%
val_df.type.value_counts()
# Out:
# query        1671
# reference      34
# Name: type, dtype: int64

# %%
# trn_df[trn_df.type == 'query'].label.value_counts().hist(bins=25)
sns.distplot(trn_df[trn_df.type == 'query'].label.value_counts(), norm_hist=False, kde=False,bins=15)

# %%
sns.distplot(val_df[val_df.type == 'query'].label.value_counts(), norm_hist=False, kde=False, bins= 20)

# %% [markdown]
# #### Datset and DataLoader

# %%
args.episodes_per_epoch = roundup((trn_df[trn_df.type == 'reference'].label.nunique())/args.k_train, 1)
args.evaluation_episodes = 100 # setting small value, anyway validation set is almost useless here

# %%
def get_aug_custom(re_size=224, to_size=224, train=True):
    augs = [A.Resize(height=re_size, width=re_size)]
    if train:
        augs.extend([
            A.RandomCrop(height=to_size, width=to_size),
            A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.3, rotate_limit=30, p=0.75),
            A.RandomBrightnessContrast(brightness_limit=0.5, contrast_limit=0.5, p=0.75),
            A.Blur(p=0.5),
            A.Cutout(max_h_size=to_size//12, max_w_size=to_size//12, p=0.5),
        ])
    else:
        augs.extend([A.CenterCrop(height=to_size, width=to_size)])
    return A.Compose(augs + [A.Normalize()])

# %%
def get_aug_plus_custom(re_size=224, to_size=224, augment='train', normalize='imagenet'):
    augs = [A.Resize(height=re_size, width=re_size)]
    if augment == 'train':
        augs.extend([
            A.RandomCrop(height=to_size, width=to_size),
            A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.3, rotate_limit=30, p=0.75),
            A.RandomBrightnessContrast(brightness_limit=0.5, contrast_limit=0.5, p=0.75),
            A.Blur(p=0.5),
            A.Cutout(max_h_size=to_size//12, max_w_size=to_size//12, p=0.5),
        ])
    elif augment == 'train_hard':
        augs.extend([
            A.RandomCrop(height=to_size, width=to_size),
            A.IAAAffine(scale=1.3, translate_percent=0.2, translate_px=None,
                                        rotate=40, shear=20),
            A.RandomBrightnessContrast(brightness_limit=0.5, contrast_limit=0.5, p=0.75),
            A.IAAPerspective(p=1),
            A.IAAAdditiveGaussianNoise(p=0.2),
            A.Blur(p=0.5),
            A.Cutout(max_h_size=to_size//12, max_w_size=to_size//12, p=0.5),
        ])
    elif augment == 'test':
        augs.extend([
            A.CenterCrop(height=to_size, width=to_size)
        ])
    elif augment == 'tta':
        augs.extend([
            A.IAAAffine(scale=1.05, translate_percent=0.1, translate_px=None, 
                        rotate=20, shear=10),
            A.CenterCrop(height=to_size, width=to_size),
        ])
    else:
        raise Exception(f'aug level not supported: {augment}')
    return A.Compose(augs + [A.Normalize()])

# %%
class GrocerImages(Dataset):
    def __init__(self, path, df, re_size=256, to_size=256, train=True):
        self.df = df.reset_index(drop=True)
        # Index should be same in reference and query df compared to original df
        self.support_df = self.df[self.df.type == 'reference']
        self.query_df = self.df[self.df.type == 'query']
        
        self.classes = sorted(list(set(self.support_df.label_id.values)))

        self.loader = get_img_loader(path, to_gray=False)
        self.transform = get_aug_custom(re_size=re_size, to_size=to_size, train=train)
        self.to_tensor = transforms.ToTensor()

    def __getitem__(self, item):
        instance = self.loader(self.df.loc[item, 'image_path'])
        instance = self.transform(image=instance)['image']
        instance = self.to_tensor(instance)
        label = self.df.loc[item, 'label_id']
        return instance, label

    def __len__(self):
        return len(self.df)

    def num_classes(self):
        return len(self.cls2imgs)

# %%
class GrocerImages_plus(GrocerImages):
    def __init__(self, path, df, re_size=256, to_size=224, part=0, n_part=1,
                 augment='normal', normalize='samplewise'):
        super().__init__(path, df, re_size=re_size, to_size=to_size, train=(augment=='train'))
        self.df = df.reset_index(drop=True)
        # Index should be same in reference and query df compared to original df

        self.transform = get_aug_plus_custom(re_size=re_size, to_size=to_size, augment=augment, normalize=normalize)
        self.part, self.n_part = part, n_part

    def __getitem__(self, item):
        instance = self.loader(self.df.loc[item, 'image_path'])
#         if self.n_part > 1:
#             instance = partition_np_image(instance, self.part, n_part=self.n_part)
        instance = self.transform(image=instance)['image']
        instance = self.to_tensor(instance)
        label = self.df.loc[item, 'label_id']
        return instance, label

# %%
class NShotTaskSampler_custom(Sampler):
    def __init__(self, dataset, episodes_per_epoch, n, k, q):

        super(NShotTaskSampler_custom, self).__init__(dataset)
        self.episodes_per_epoch = episodes_per_epoch
        self.dataset = dataset

        # TODO: Raise errors if initialise badly
        self.k = k
        self.n = n
        self.q = q

    def __len__(self):
        return self.episodes_per_epoch

    def __iter__(self):
        for _ in range(self.episodes_per_epoch):
            batch = []
            # Get random classes
            support_df = self.dataset.support_df
            query_df = self.dataset.query_df
            episode_classes = np.random.choice(support_df['label_id'].unique(), size=self.k, replace=False)
            
            #df = self.dataset.df[self.dataset.df['class_id'].isin(episode_classes)]

            for k in episode_classes:
                # Select support examples
                support = support_df[support_df['label_id'] == k].sample(self.n)

                for i, s in support.iterrows():
                    batch.append(i)

            for k in episode_classes:
                try :
                    query = query_df[query_df['label_id'] == k].sample(self.q)
                except:
                    query = query_df[query_df['label_id'] == k].sample(self.q, replace=True)
                for i, q in query.iterrows():
                    batch.append(i)

        yield np.stack(batch)

# %%
# Dataloader
background = GrocerImages_plus(path='/', df=trn_df, re_size=RE_SZ, to_size=SZ, augment='train', normalize = 'imagenet')
background_taskloader = DataLoader(background, batch_sampler=NShotTaskSampler_custom(background, args.episodes_per_epoch, 
                            args.n_train, args.k_train, args.q_train),num_workers=8)

evaluation = GrocerImages(path='/', df=val_df, re_size=RE_SZ, to_size=SZ, train=False)

evaluation_taskloader = DataLoader(evaluation, 
            batch_sampler=NShotTaskSampler_custom(evaluation, args.episodes_per_epoch, args.n_test, args.k_test, args.q_test),
    num_workers=8)

# %% [markdown]
# #### Loaders Checking

# %%
x = next(iter(background_taskloader))

sx = x[0][:args.k_train*args.n_train, ...]
qx = x[0][args.k_train*args.n_train:, ...]

sy = x[1][:args.k_train*args.n_train]
qy = x[1][args.k_train*args.n_train:]

sorted(sy.unique()) == sorted(qy.unique())
# Out:
# True

# %%
# %matplotlib inline
def show(img):
    img1 = img.numpy()
    img1 = np.transpose(img1, (1,2,0))
    img1 = (img1*std1) + mean1
    #img = img*255.
#     print(img1.shape)
    plt.imshow(img1)#, interpolation = 'nearest')
#     return img1

mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

mean1 = mean[None, None, :]
std1 = std[None, None, :]

# %%
idx = np.random.randint(0, args.k_train)
imgs = torch.cat((sx[sy == sy.unique()[idx], ...], qx[qy ==sy.unique()[idx], ...]), dim=0)

imgs = torch.FloatTensor(imgs)

# %%
show(imgs[0]);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show(imgs[1]);

# %%
show(imgs[2])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Modeling
# * Pretraining with retail data
# * lr_finder
# * Freeze Initial layers and train only last layers
# * fit_one_cycle
# * disriminative learning rates

# %% [markdown]
# #### Lr_Finder

# %%
from few_shot.proto import proto_net_episode
from few_shot.core import prepare_nshot_task
from torch_lr_finder import LRFinder
from torch import optim
# Out:
# WARNING:torch_lr_finder.lr_finder:To enable mixed precision training, please install `apex`. Or you can re-install this package by the following command:
#   pip install torch-lr-finder -v --global-option="amp"

# %%
from torch_lr_finder.lr_finder import DataLoaderIterWrapper

# %%
feature_model = get_resnet34(device=device, weight_file=args.init_weight)

# %%
criterion = torch.nn.NLLLoss()

# %%
optimizer = optim.Adam(feature_model.parameters(), lr=1e-7)

# %%
class lr_finder_proto(LRFinder):
    
    def __init__(self, model, optimizer, criterion, device=None, memory_cache=True, cache_dir=None):
        super().__init__(model, optimizer, criterion, device=None, memory_cache=True, cache_dir=None)
        self.prepare_batch = prepare_nshot_task(args.n_train, args.k_train, args.q_train)
    
#     def range_test(self, train_loader, val_loader=None, start_lr=None, end_lr=10, num_iter=100, step_mode="exp",
#                     smooth_f=0.05, diverge_th=5, accumulation_steps=1):
#         super().__init__(train_loader, val_loader=None, start_lr=None, end_lr=10, num_iter=100, step_mode="exp",
#                     smooth_f=0.05, diverge_th=5, accumulation_steps=1)
#         self.dl = DataLoaderIterWrapper(train_loader)
    
    def _train_batch(self, iter_wrapper, accumulation_steps):
#         self.model.train()
        total_loss = None  # for late initialization

#         self.optimizer.zero_grad()
        for i in range(accumulation_steps):
            batch = iter_wrapper.get_batch()
            inputs, labels = self.prepare_batch(batch)
#             print(inputs.shape, labels.shape)
            # Forward pass
            loss, y_pred = proto_net_episode(self.model, self.optimizer, self.criterion, inputs, labels, 
                                        args.n_train, args.k_train, args.q_train, distance ='l2' ,train =True)
            
            # Loss should be averaged in each step
            loss /= accumulation_steps

            # Backward pass
#             loss.backward()

            if total_loss is None:
                total_loss = loss
            else:
                total_loss += loss
        
        if len(self.history['lr'])>0:
            print(loss, self.history["lr"][-1])

        return total_loss.item()

# %%
lr_finder = lr_finder_proto(feature_model, optimizer, criterion, device="cuda", cache_dir = 'logs')

# %%
lr_finder.range_test(background_taskloader, end_lr=100, num_iter=150, smooth_f=0.5)
# Out:
# HBox(children=(IntProgress(value=0, max=150), HTML(value='')))
# tensor(61.4375, device='cuda:0', grad_fn=<DivBackward0>) 1.1481536214968827e-07
# tensor(61.9976, device='cuda:0', grad_fn=<DivBackward0>) 1.318256738556407e-07
# tensor(71.0080, device='cuda:0', grad_fn=<DivBackward0>) 1.513561248436208e-07
# tensor(60.3957, device='cuda:0', grad_fn=<DivBackward0>) 1.7378008287493754e-07
# tensor(73.2743, device='cuda:0', grad_fn=<DivBackward0>) 1.9952623149688795e-07
# tensor(68.5376, device='cuda:0', grad_fn=<DivBackward0>) 2.290867652767773e-07
# tensor(68.3815, device='cuda:0', grad_fn=<DivBackward0>) 2.630267991895382e-07
# tensor(38.0908, device='cuda:0', grad_fn=<DivBackward0>) 3.0199517204020165e-07
# tensor(66.4267, device='cuda:0', grad_fn=<DivBackward0>) 3.467368504525316e-07
# tensor(83.4415, device='cuda:0', grad_fn=<DivBackward0>) 3.981071705534972e-07
# tensor(79.8378, device='cuda:0', grad_fn=<DivBackward0>) 4.5708818961487505e-07
# tensor(68.2389, device='cuda:0', grad_fn=<DivBackward0>) 5.248074602497726e-07
# tensor(87.0141, device='cuda:0', grad_fn=<DivBackward0>) 6.025595860743577e-07
# tensor(68.6929, device='cuda:0', grad_fn=<DivBackward0>) 6.918309709189365e-07
# tensor(63.9252, device='cuda:0', grad_fn=<DivBackward0>) 7.943282347242816e-07
# tensor(55.4155, device='cuda:0', grad_fn=<DivBackward0>) 9.120108393559097e-07
# tensor(49.4683, device='cuda:0', grad_fn=<DivBackward0>) 1.0471285480508994e-06
# tensor(56.1424, device='cuda:0', grad_fn=<DivBackward0>) 1.2022644346174128e-06
# tensor(67.6019, device='cuda:0', grad_fn=<DivBackward0>) 1.380384264602885e-06
# tensor(79.5780, device='cuda:0', grad_fn=<DivBackward0>) 1.5848931924611134e-06
# tensor(74.5951, device='cuda:0', grad_fn=<DivBackward0>) 1.819700858609984e-06
# tensor(62.5028, device='cuda:0', grad_fn=<DivBackward0>) 2.0892961308540394e-06
# tensor(61.4614, device='cuda:0', grad_fn=<DivBackward0>) 2.3988329190194897e-06
# tensor(68.7025, device='cuda:0', grad_fn=<DivBackward0>) 2.7542287033381663e-06
# tensor(55.0516, device='cuda:0', grad_fn=<DivBackward0>) 3.1622776601683788e-06
# tensor(73.1564, device='cuda:0', grad_fn=<DivBackward0>) 3.630780547701014e-06
# tensor(54.1391, device='cuda:0', grad_fn=<DivBackward0>) 4.168693834703353e-06
# tensor(55.6842, device='cuda:0', grad_fn=<DivBackward0>) 4.786300923226384e-06
# tensor(59.6828, device='cuda:0', grad_fn=<DivBackward0>) 5.495408738576245e-06
# tensor(41.6770, device='cuda:0', grad_fn=<DivBackward0>) 6.309573444801934e-06
# tensor(51.2160, device='cuda:0', grad_fn=<DivBackward0>) 7.244359600749901e-06
# tensor(37.3711, device='cuda:0', grad_fn=<DivBackward0>) 8.317637711026713e-06
# tensor(61.4181, device='cuda:0', grad_fn=<DivBackward0>) 9.549925860214359e-06
# tensor(51.0570, device='cuda:0', grad_fn=<DivBackward0>) 1.0964781961431847e-05
# tensor(43.7567, device='cuda:0', grad_fn=<DivBackward0>) 1.2589254117941671e-05
# tensor(49.1912, device='cuda:0', grad_fn=<DivBackward0>) 1.4454397707459272e-05
# tensor(38.6889, device='cuda:0', grad_fn=<DivBackward0>) 1.659586907437561e-05
# tensor(27.2922, device='cuda:0', grad_fn=<DivBackward0>) 1.905460717963248e-05
# tensor(33.1867, device='cuda:0', grad_fn=<DivBackward0>) 2.187761623949553e-05
# tensor(28.1790, device='cuda:0', grad_fn=<DivBackward0>) 2.5118864315095798e-05
# tensor(22.2853, device='cuda:0', grad_fn=<DivBackward0>) 2.884031503126605e-05
# tensor(18.7305, device='cuda:0', grad_fn=<DivBackward0>) 3.3113112148259124e-05
# tensor(23.4928, device='cuda:0', grad_fn=<DivBackward0>) 3.8018939632056124e-05
# tensor(27.4773, device='cuda:0', grad_fn=<DivBackward0>) 4.36515832240166e-05
# tensor(18.4652, device='cuda:0', grad_fn=<DivBackward0>) 5.011872336272722e-05
# tensor(17.1986, device='cuda:0', grad_fn=<DivBackward0>) 5.754399373371566e-05
# tensor(23.4885, device='cuda:0', grad_fn=<DivBackward0>) 6.606934480075963e-05
# tensor(9.9002, device='cuda:0', grad_fn=<DivBackward0>) 7.585775750291839e-05
# tensor(12.9714, device='cuda:0', grad_fn=<DivBackward0>) 8.709635899560806e-05
# tensor(14.9863, device='cuda:0', grad_fn=<DivBackward0>) 9.999999999999996e-05
# tensor(13.8990, device='cuda:0', grad_fn=<DivBackward0>) 0.00011481536214968832
# tensor(9.4967, device='cuda:0', grad_fn=<DivBackward0>) 0.00013182567385564074
# tensor(8.0490, device='cuda:0', grad_fn=<DivBackward0>) 0.0001513561248436208
# tensor(10.0752, device='cuda:0', grad_fn=<DivBackward0>) 0.00017378008287493747
# tensor(3.1915, device='cuda:0', grad_fn=<DivBackward0>) 0.00019952623149688785
# tensor(14.4818, device='cuda:0', grad_fn=<DivBackward0>) 0.0002290867652767774
# tensor(8.1839, device='cuda:0', grad_fn=<DivBackward0>) 0.0002630267991895382
# tensor(6.9382, device='cuda:0', grad_fn=<DivBackward0>) 0.0003019951720402016
# tensor(2.9567, device='cuda:0', grad_fn=<DivBackward0>) 0.00034673685045253147
# tensor(9.9019, device='cuda:0', grad_fn=<DivBackward0>) 0.0003981071705534974
# tensor(5.4758, device='cuda:0', grad_fn=<DivBackward0>) 0.0004570881896148751
# tensor(6.4602, device='cuda:0', grad_fn=<DivBackward0>) 0.0005248074602497725
# tensor(4.5424, device='cuda:0', grad_fn=<DivBackward0>) 0.0006025595860743576
# tensor(3.6349, device='cuda:0', grad_fn=<DivBackward0>) 0.0006918309709189369
# tensor(5.9958, device='cuda:0', grad_fn=<DivBackward0>) 0.0007943282347242816
# tensor(1.8712, device='cuda:0', grad_fn=<DivBackward0>) 0.0009120108393559097
# tensor(3.6921, device='cuda:0', grad_fn=<DivBackward0>) 0.0010471285480508994
# tensor(5.0455, device='cuda:0', grad_fn=<DivBackward0>) 0.0012022644346174124
# tensor(7.0209, device='cuda:0', grad_fn=<DivBackward0>) 0.0013803842646028853
# tensor(3.7636, device='cuda:0', grad_fn=<DivBackward0>) 0.0015848931924611136
# tensor(4.0656, device='cuda:0', grad_fn=<DivBackward0>) 0.0018197008586099833
# tensor(5.6267, device='cuda:0', grad_fn=<DivBackward0>) 0.0020892961308540386
# tensor(8.5992, device='cuda:0', grad_fn=<DivBackward0>) 0.0023988329190194916
# tensor(4.1193, device='cuda:0', grad_fn=<DivBackward0>) 0.002754228703338167
# tensor(4.5946, device='cuda:0', grad_fn=<DivBackward0>) 0.003162277660168379
# tensor(12.3723, device='cuda:0', grad_fn=<DivBackward0>) 0.0036307805477010166
# tensor(5.5622, device='cuda:0', grad_fn=<DivBackward0>) 0.004168693834703352
# tensor(6.4710, device='cuda:0', grad_fn=<DivBackward0>) 0.004786300923226385
# tensor(5.4013, device='cuda:0', grad_fn=<DivBackward0>) 0.0054954087385762395
# tensor(14.3500, device='cuda:0', grad_fn=<DivBackward0>) 0.006309573444801931
# tensor(12.2591, device='cuda:0', grad_fn=<DivBackward0>) 0.007244359600749905
# tensor(8.0662, device='cuda:0', grad_fn=<DivBackward0>) 0.008317637711026704
# tensor(17.3278, device='cuda:0', grad_fn=<DivBackward0>) 0.00954992586021436
# tensor(23.2013, device='cuda:0', grad_fn=<DivBackward0>) 0.010964781961431861
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
lr_finder.plot(skip_start=30, skip_end=0) # to inspect the loss-learning rate graph

# %%
lr_finder.reset() # to reset the model and optimizer to their initial state

# %% [markdown]
# #### Training

# %%
feature_model = get_resnet34(device=device, weight_file=args.init_weight)

# %%
args.param_str = f'BC_q{args.q_train}k{args.k_train}_rq5_ref1.5k'
args.param_str
# Out:
# 'BC_q2k100_rq5_ref1.5k'

# %%
train_proto_net(args,
                model=feature_model,
                device=device,
                path='.',
                n_epochs=args.n_epochs,
                background_taskloader=background_taskloader,
                evaluation_taskloader=evaluation_taskloader,
                drop_lr_every=args.drop_lr_every,
                evaluation_episodes=args.evaluation_episodes,
                episodes_per_epoch=args.episodes_per_epoch,
                lr=args.lr,
               )
# Out:
# Epoch 1:   0%|          | 0/16 [00:00<?, ?it/s]
# Begin training...
# Epoch 1:  12%|█▎        | 2/16 [00:11<01:31,  6.53s/it, loss=63.9, categorical_accuracy=0.52, val_1-shot_34-way_acc=0.218]
# Epoch 2:  12%|█▎        | 2/16 [00:11<01:30,  6.49s/it, loss=43.6, categorical_accuracy=0.58, val_1-shot_34-way_acc=0.271]
# Epoch 3:  12%|█▎        | 2/16 [00:11<01:30,  6.46s/it, loss=37, categorical_accuracy=0.665, val_1-shot_34-way_acc=0.341]
# Epoch 4:  12%|█▎        | 2/16 [00:11<01:31,  6.56s/it, loss=34.5, categorical_accuracy=0.695, val_1-shot_34-way_acc=0.324]
# Epoch 5:  12%|█▎        | 2/16 [00:10<01:28,  6.34s/it, loss=30.3, categorical_accuracy=0.71, val_1-shot_34-way_acc=0.388]
# Epoch 6:  12%|█▎        | 2/16 [00:10<01:28,  6.35s/it, loss=26.5, categorical_accuracy=0.78, val_1-shot_34-way_acc=0.482]
# Epoch 7:  12%|█▎        | 2/16 [00:10<01:28,  6.36s/it, loss=17.2, categorical_accuracy=0.785, val_1-shot_34-way_acc=0.506]
# Epoch 8:  12%|█▎        | 2/16 [00:10<01:28,  6.29s/it, loss=12.9, categorical_accuracy=0.845, val_1-shot_34-way_acc=0.5]
# Epoch 9:  12%|█▎        | 2/16 [00:10<01:28,  6.32s/it, loss=17, categorical_accuracy=0.825, val_1-shot_34-way_acc=0.524]
# Epoch 10:  12%|█▎        | 2/16 [00:11<01:34,  6.78s/it, loss=14.9, categorical_accuracy=0.845, val_1-shot_34-way_acc=0.494]
# Epoch 11:  12%|█▎        | 2/16 [00:10<01:28,  6.31s/it, loss=18.5, categorical_accuracy=0.81, val_1-shot_34-way_acc=0.506]
# Epoch 12:  12%|█▎        | 2/16 [00:10<01:27,  6.25s/it, loss=15.1, categorical_accuracy=0.83, val_1-shot_34-way_acc=0.512]
# Epoch 13:  12%|█▎        | 2/16 [00:10<01:27,  6.23s/it, loss=11.7, categorical_accuracy=0.83, val_1-shot_34-way_acc=0.547]
# Epoch 14:  12%|█▎        | 2/16 [00:10<01:26,  6.15s/it, loss=9.88, categorical_accuracy=0.88, val_1-shot_34-way_acc=0.529]
# Epoch 15:  12%|█▎        | 2/16 [00:11<01:30,  6.47s/it, loss=6.72, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.494]
# Epoch 16:  12%|█▎        | 2/16 [00:10<01:29,  6.39s/it, loss=9.2, categorical_accuracy=0.9, val_1-shot_34-way_acc=0.524]
# Epoch 17:  12%|█▎        | 2/16 [00:10<01:28,  6.30s/it, loss=6.13, categorical_accuracy=0.91, val_1-shot_34-way_acc=0.494]
# Epoch 18:  12%|█▎        | 2/16 [00:10<01:26,  6.19s/it, loss=10.3, categorical_accuracy=0.885, val_1-shot_34-way_acc=0.553]
# Epoch 19:  12%|█▎        | 2/16 [00:11<01:33,  6.71s/it, loss=8.26, categorical_accuracy=0.87, val_1-shot_34-way_acc=0.506]
# Epoch 20:  12%|█▎        | 2/16 [00:10<01:27,  6.23s/it, loss=4.03, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.459]
# Epoch 21:  12%|█▎        | 2/16 [00:10<01:27,  6.28s/it, loss=4.8, categorical_accuracy=0.905, val_1-shot_34-way_acc=0.488]
# Epoch 22:  12%|█▎        | 2/16 [00:11<01:34,  6.73s/it, loss=6.27, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.453]
# Epoch 23:  12%|█▎        | 2/16 [00:11<01:36,  6.87s/it, loss=5.45, categorical_accuracy=0.915, val_1-shot_34-way_acc=0.465]
# Epoch 24:  12%|█▎        | 2/16 [00:11<01:33,  6.69s/it, loss=2.76, categorical_accuracy=0.935, val_1-shot_34-way_acc=0.435]
# Epoch 25:  12%|█▎        | 2/16 [00:10<01:24,  6.03s/it, loss=7.41, categorical_accuracy=0.895, val_1-shot_34-way_acc=0.453]
# Epoch 26:  12%|█▎        | 2/16 [00:10<01:29,  6.40s/it, loss=3.62, categorical_accuracy=0.91, val_1-shot_34-way_acc=0.447]
# Epoch 27:  12%|█▎        | 2/16 [00:10<01:29,  6.41s/it, loss=3.61, categorical_accuracy=0.925, val_1-shot_34-way_acc=0.476]
# Epoch 28:  12%|█▎        | 2/16 [00:11<01:32,  6.63s/it, loss=6.14, categorical_accuracy=0.925, val_1-shot_34-way_acc=0.435]
# Epoch 29:  12%|█▎        | 2/16 [00:12<01:39,  7.12s/it, loss=3.98, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.471]
# Epoch 30:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=2.23, categorical_accuracy=0.93, val_1-shot_34-way_acc=0.506]
# Epoch 31:  12%|█▎        | 2/16 [00:11<01:36,  6.90s/it, loss=3.94, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.518]
# Epoch 32:  12%|█▎        | 2/16 [00:11<01:37,  6.95s/it, loss=1.27, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.571]
# Epoch 33:  12%|█▎        | 2/16 [00:11<01:38,  7.04s/it, loss=1.46, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.547]
# Epoch 34:  12%|█▎        | 2/16 [00:11<01:30,  6.47s/it, loss=5.29, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.559]
# Epoch 35:  12%|█▎        | 2/16 [00:11<01:37,  6.98s/it, loss=2.91, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.547]
# Epoch 36:  12%|█▎        | 2/16 [00:12<01:39,  7.08s/it, loss=3.57, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.553]
# Epoch 37:  12%|█▎        | 2/16 [00:11<01:32,  6.60s/it, loss=4.01, categorical_accuracy=0.94, val_1-shot_34-way_acc=0.565]
# Epoch 38:  12%|█▎        | 2/16 [00:10<01:29,  6.36s/it, loss=3.02, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.594]
# Epoch 39:  12%|█▎        | 2/16 [00:11<01:37,  6.93s/it, loss=2.67, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.565]
# Epoch 40:  12%|█▎        | 2/16 [00:11<01:34,  6.72s/it, loss=2.16, categorical_accuracy=0.93, val_1-shot_34-way_acc=0.553]
# Epoch 41:  12%|█▎        | 2/16 [00:11<01:31,  6.53s/it, loss=5.2, categorical_accuracy=0.905, val_1-shot_34-way_acc=0.6]
# Epoch 42:  12%|█▎        | 2/16 [00:11<01:32,  6.62s/it, loss=2.56, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.606]
# Epoch 43:  12%|█▎        | 2/16 [00:11<01:31,  6.52s/it, loss=3.9, categorical_accuracy=0.93, val_1-shot_34-way_acc=0.624]
# Epoch 44:  12%|█▎        | 2/16 [00:11<01:37,  6.96s/it, loss=9.36, categorical_accuracy=0.9, val_1-shot_34-way_acc=0.606]
# Epoch 45:  12%|█▎        | 2/16 [00:12<01:40,  7.16s/it, loss=1.46, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.618]
# Epoch 46:  12%|█▎        | 2/16 [00:11<01:31,  6.55s/it, loss=5, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.659]
# Epoch 47:  12%|█▎        | 2/16 [00:12<01:41,  7.25s/it, loss=4.62, categorical_accuracy=0.91, val_1-shot_34-way_acc=0.588]
# Epoch 48:  12%|█▎        | 2/16 [00:10<01:28,  6.34s/it, loss=2.62, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.606]
# Epoch 49:  12%|█▎        | 2/16 [00:11<01:29,  6.41s/it, loss=1.17, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.618]
# Epoch 50:  12%|█▎        | 2/16 [00:11<01:36,  6.91s/it, loss=3.27, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.659]
# Epoch 51:  12%|█▎        | 2/16 [00:11<01:35,  6.81s/it, loss=0.926, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.6]
# Epoch 52:  12%|█▎        | 2/16 [00:11<01:32,  6.63s/it, loss=6.61, categorical_accuracy=0.91, val_1-shot_34-way_acc=0.641]
# Epoch 53:  12%|█▎        | 2/16 [00:11<01:31,  6.54s/it, loss=2.47, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.629]
# Epoch 54:  12%|█▎        | 2/16 [00:11<01:30,  6.48s/it, loss=1.89, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.565]
# Epoch 55:  12%|█▎        | 2/16 [00:10<01:29,  6.36s/it, loss=2.95, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.565]
# Epoch 56:  12%|█▎        | 2/16 [00:11<01:32,  6.61s/it, loss=1.41, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.635]
# Epoch 57:  12%|█▎        | 2/16 [00:11<01:30,  6.44s/it, loss=6.03, categorical_accuracy=0.92, val_1-shot_34-way_acc=0.576]
# Epoch 58:  12%|█▎        | 2/16 [00:11<01:31,  6.52s/it, loss=3.39, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.588]
# Epoch 59:  12%|█▎        | 2/16 [00:11<01:32,  6.62s/it, loss=1.95, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.612]
# Epoch 60:  12%|█▎        | 2/16 [00:11<01:32,  6.60s/it, loss=3.1, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.629]
# Epoch 61:  12%|█▎        | 2/16 [00:11<01:31,  6.54s/it, loss=1.45, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.641]
# Epoch 62:  12%|█▎        | 2/16 [00:11<01:34,  6.76s/it, loss=2.17, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.653]
# Epoch 63:  12%|█▎        | 2/16 [00:11<01:32,  6.62s/it, loss=2.43, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.671]
# Epoch 64:  12%|█▎        | 2/16 [00:11<01:30,  6.45s/it, loss=1.9, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.629]
# Epoch 65:  12%|█▎        | 2/16 [00:11<01:35,  6.83s/it, loss=3.35, categorical_accuracy=0.91, val_1-shot_34-way_acc=0.635]
# Epoch 66:  12%|█▎        | 2/16 [00:11<01:31,  6.54s/it, loss=5.55, categorical_accuracy=0.915, val_1-shot_34-way_acc=0.647]
# Epoch 67:  12%|█▎        | 2/16 [00:11<01:30,  6.49s/it, loss=6.27, categorical_accuracy=0.895, val_1-shot_34-way_acc=0.676]
# Epoch 68:  12%|█▎        | 2/16 [00:11<01:30,  6.45s/it, loss=3.46, categorical_accuracy=0.935, val_1-shot_34-way_acc=0.635]
# Epoch 69:  12%|█▎        | 2/16 [00:11<01:33,  6.68s/it, loss=2.27, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.641]
# Epoch 70:  12%|█▎        | 2/16 [00:11<01:31,  6.51s/it, loss=2.49, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.676]
# Epoch 71:  12%|█▎        | 2/16 [00:10<01:27,  6.23s/it, loss=3.51, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.635]
# Epoch 72:  12%|█▎        | 2/16 [00:11<01:31,  6.51s/it, loss=3.83, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.647]
# Epoch 73:  12%|█▎        | 2/16 [00:11<01:29,  6.40s/it, loss=0.919, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.641]
# Epoch 74:  12%|█▎        | 2/16 [00:11<01:32,  6.59s/it, loss=1.35, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.671]
# Epoch 75:  12%|█▎        | 2/16 [00:12<01:39,  7.10s/it, loss=2.33, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.653]
# Epoch 76:  12%|█▎        | 2/16 [00:11<01:33,  6.69s/it, loss=1.84, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.612]
# Epoch 77:  12%|█▎        | 2/16 [00:11<01:30,  6.45s/it, loss=1.35, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.653]
# Epoch 78:  12%|█▎        | 2/16 [00:11<01:37,  6.93s/it, loss=1.04, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.647]
# Epoch 79:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=0.987, categorical_accuracy=0.985, val_1-shot_34-way_acc=0.676]
# Epoch 80:  12%|█▎        | 2/16 [00:12<01:44,  7.49s/it, loss=3, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.671]
# Epoch 81:  12%|█▎        | 2/16 [00:11<01:34,  6.75s/it, loss=2.35, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.629]
# Epoch 82:  12%|█▎        | 2/16 [00:11<01:36,  6.88s/it, loss=2.32, categorical_accuracy=0.94, val_1-shot_34-way_acc=0.688]
# Epoch 83:  12%|█▎        | 2/16 [00:11<01:32,  6.63s/it, loss=2.8, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.688]
# Epoch 84:  12%|█▎        | 2/16 [00:11<01:36,  6.93s/it, loss=2.82, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.653]
# Epoch 85:  12%|█▎        | 2/16 [00:10<01:28,  6.34s/it, loss=1.9, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.641]
# Epoch 86:  12%|█▎        | 2/16 [00:11<01:34,  6.78s/it, loss=3.77, categorical_accuracy=0.93, val_1-shot_34-way_acc=0.647]
# Epoch 87:  12%|█▎        | 2/16 [00:11<01:32,  6.62s/it, loss=2.03, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.712]
# Epoch 88:  12%|█▎        | 2/16 [00:11<01:32,  6.59s/it, loss=1.52, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.688]
# Epoch 89:  12%|█▎        | 2/16 [00:11<01:31,  6.50s/it, loss=1.63, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.629]
# Epoch 90:  12%|█▎        | 2/16 [00:11<01:33,  6.71s/it, loss=0.331, categorical_accuracy=0.99, val_1-shot_34-way_acc=0.665]
# Epoch 91:  12%|█▎        | 2/16 [00:11<01:36,  6.88s/it, loss=2.02, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.718]
# Epoch 92:  12%|█▎        | 2/16 [00:11<01:37,  6.94s/it, loss=1.44, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.688]
# Epoch 93:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=1.07, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.712]
# Epoch 94:  12%|█▎        | 2/16 [00:11<01:36,  6.88s/it, loss=1.6, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.682]
# Epoch 95:  12%|█▎        | 2/16 [00:11<01:33,  6.69s/it, loss=0.782, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.665]
# Epoch 96:  12%|█▎        | 2/16 [00:11<01:30,  6.45s/it, loss=2.6, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.718]
# Epoch 97:  12%|█▎        | 2/16 [00:11<01:33,  6.71s/it, loss=1.39, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.7]
# Epoch 98:  12%|█▎        | 2/16 [00:11<01:32,  6.61s/it, loss=2.6, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.688]
# Epoch 99:  12%|█▎        | 2/16 [00:11<01:36,  6.91s/it, loss=2.3, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.682]
# Epoch 100:  12%|█▎        | 2/16 [00:11<01:30,  6.44s/it, loss=2.58, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.694]
# Finished.

# %%
train_proto_net(args,
                model=feature_model,
                device=device,
                path='.',
                n_epochs=50,
                background_taskloader=background_taskloader,
                evaluation_taskloader=evaluation_taskloader,
                drop_lr_every=args.drop_lr_every,
                evaluation_episodes=args.evaluation_episodes,
                episodes_per_epoch=args.episodes_per_epoch,
                lr=args.lr/10,
               )
# Out:
# Epoch 1:   0%|          | 0/16 [00:00<?, ?it/s]
# Begin training...
# Epoch 1:  12%|█▎        | 2/16 [00:11<01:30,  6.43s/it, loss=1.54, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.694]
# Epoch 2:  12%|█▎        | 2/16 [00:10<01:27,  6.22s/it, loss=1.84, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.676]
# Epoch 3:  12%|█▎        | 2/16 [00:11<01:37,  7.00s/it, loss=1.71, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.659]
# Epoch 4:  12%|█▎        | 2/16 [00:11<01:37,  6.99s/it, loss=4.74, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.7]
# Epoch 5:  12%|█▎        | 2/16 [00:11<01:33,  6.64s/it, loss=0.389, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.718]
# Epoch 6:  12%|█▎        | 2/16 [00:11<01:32,  6.58s/it, loss=1.33, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.682]
# Epoch 7:  12%|█▎        | 2/16 [00:11<01:30,  6.44s/it, loss=3.64, categorical_accuracy=0.935, val_1-shot_34-way_acc=0.671]
# Epoch 8:  12%|█▎        | 2/16 [00:11<01:35,  6.80s/it, loss=1.14, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.724]
# Epoch 9:  12%|█▎        | 2/16 [00:11<01:31,  6.55s/it, loss=2.06, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.641]
# Epoch 10:  12%|█▎        | 2/16 [00:11<01:35,  6.80s/it, loss=2.48, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.635]
# Epoch 11:  12%|█▎        | 2/16 [00:11<01:35,  6.86s/it, loss=2.96, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.712]
# Epoch 12:  12%|█▎        | 2/16 [00:11<01:30,  6.50s/it, loss=1.6, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.694]
# Epoch 13:  12%|█▎        | 2/16 [00:11<01:30,  6.46s/it, loss=4.35, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.7]
# Epoch 14:  12%|█▎        | 2/16 [00:11<01:31,  6.50s/it, loss=0.891, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.694]
# Epoch 15:  12%|█▎        | 2/16 [00:11<01:33,  6.69s/it, loss=0.612, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.694]
# Epoch 16:  12%|█▎        | 2/16 [00:11<01:37,  6.95s/it, loss=1.06, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.665]
# Epoch 17:  12%|█▎        | 2/16 [00:11<01:33,  6.67s/it, loss=2.48, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.641]
# Epoch 18:  12%|█▎        | 2/16 [00:11<01:32,  6.63s/it, loss=3.03, categorical_accuracy=0.935, val_1-shot_34-way_acc=0.729]
# Epoch 19:  12%|█▎        | 2/16 [00:11<01:33,  6.70s/it, loss=2.27, categorical_accuracy=0.935, val_1-shot_34-way_acc=0.694]
# Epoch 20:  12%|█▎        | 2/16 [00:11<01:30,  6.43s/it, loss=1.07, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.682]
# Epoch 21:  12%|█▎        | 2/16 [00:11<01:29,  6.40s/it, loss=2.12, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.635]
# Epoch 22:  12%|█▎        | 2/16 [00:11<01:34,  6.76s/it, loss=0.692, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.724]
# Epoch 23:  12%|█▎        | 2/16 [00:11<01:29,  6.36s/it, loss=1.73, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.688]
# Epoch 24:  12%|█▎        | 2/16 [00:11<01:35,  6.79s/it, loss=0.394, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.724]
# Epoch 25:  12%|█▎        | 2/16 [00:11<01:32,  6.60s/it, loss=2.18, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.735]
# Epoch 26:  12%|█▎        | 2/16 [00:10<01:29,  6.37s/it, loss=1.53, categorical_accuracy=0.97, val_1-shot_34-way_acc=0.712]
# Epoch 27:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=1.16, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.688]
# Epoch 28:  12%|█▎        | 2/16 [00:11<01:32,  6.63s/it, loss=3.79, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.712]
# Epoch 29:  12%|█▎        | 2/16 [00:11<01:31,  6.55s/it, loss=1.16, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.712]
# Epoch 30:  12%|█▎        | 2/16 [00:11<01:31,  6.56s/it, loss=2.76, categorical_accuracy=0.95, val_1-shot_34-way_acc=0.765]
# Epoch 31:  12%|█▎        | 2/16 [00:11<01:31,  6.57s/it, loss=0.826, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.712]
# Epoch 32:  12%|█▎        | 2/16 [00:11<01:31,  6.57s/it, loss=2.13, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.747]
# Epoch 33:  12%|█▎        | 2/16 [00:11<01:33,  6.66s/it, loss=1.09, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.676]
# Epoch 34:  12%|█▎        | 2/16 [00:11<01:35,  6.82s/it, loss=3.4, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.718]
# Epoch 35:  12%|█▎        | 2/16 [00:12<01:39,  7.07s/it, loss=1.24, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.747]
# Epoch 36:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=1.71, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.735]
# Epoch 37:  12%|█▎        | 2/16 [00:11<01:30,  6.43s/it, loss=2.31, categorical_accuracy=0.945, val_1-shot_34-way_acc=0.718]
# Epoch 38:  12%|█▎        | 2/16 [00:11<01:37,  6.96s/it, loss=4.64, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.688]
# Epoch 39:  12%|█▎        | 2/16 [00:11<01:34,  6.75s/it, loss=0.875, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.694]
# Epoch 40:  12%|█▎        | 2/16 [00:11<01:36,  6.91s/it, loss=0.823, categorical_accuracy=0.985, val_1-shot_34-way_acc=0.718]
# Epoch 41:  12%|█▎        | 2/16 [00:11<01:32,  6.57s/it, loss=3.5, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.724]
# Epoch 42:  12%|█▎        | 2/16 [00:11<01:31,  6.52s/it, loss=1.61, categorical_accuracy=0.96, val_1-shot_34-way_acc=0.729]
# Epoch 43:  12%|█▎        | 2/16 [00:11<01:33,  6.64s/it, loss=0.952, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.718]
# Epoch 44:  12%|█▎        | 2/16 [00:11<01:33,  6.65s/it, loss=0.843, categorical_accuracy=0.98, val_1-shot_34-way_acc=0.724]
# Epoch 45:  12%|█▎        | 2/16 [00:11<01:33,  6.68s/it, loss=1.99, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.729]
# Epoch 46:  12%|█▎        | 2/16 [00:11<01:29,  6.41s/it, loss=1.84, categorical_accuracy=0.955, val_1-shot_34-way_acc=0.741]
# Epoch 47:  12%|█▎        | 2/16 [00:11<01:32,  6.62s/it, loss=2.17, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.712]
# Epoch 48:  12%|█▎        | 2/16 [00:11<01:37,  6.95s/it, loss=2.73, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.718]
# Epoch 49:  12%|█▎        | 2/16 [00:11<01:35,  6.86s/it, loss=0.927, categorical_accuracy=0.975, val_1-shot_34-way_acc=0.706]
# Epoch 50:  12%|█▎        | 2/16 [00:11<01:31,  6.57s/it, loss=1.73, categorical_accuracy=0.965, val_1-shot_34-way_acc=0.706]
# Finished.

# %%
f'{args.param_str}_e{args.n_epochs}.pth'
# Out:
# 'BC_q2k100_rq5_ref1.5k_e100.pth'

# %%
torch.save(feature_model.state_dict(), f'models/{args.param_str}_e151.pth')

# %% [markdown]
# ### Testing
# * loader for test query images
# * calculate protoypes for all reference images
# * Generate embeddings for all query images
# * Calculate distance between embeddings and prototypes
# * Save top1 and top5 accuracy

# %%
from dlcliche.image import *
sys.path.append('..') # app
sys.path.append('../..') # root
from easydict import EasyDict
from app_utils_clf import *
from whale_plus_utils import *
from config import DATA_PATH

# %%
args.n_epochs=150

# %%
# args.param_str = 'res_untrained'
exp = f'{args.param_str}'.replace(f'_res34_s1','')#_epoch{args.n_epochs}'
# exp = f'{args.param_str}_epoch{args.n_epochs}' + '_ref1.5k'
# exp = 'res_untrained_ref1.5k'
print(exp)
get_model_fn=get_resnet34
weight_file = f'models/{args.param_str}_e{args.n_epochs+1}.pth'
# weight_file = 'models/BC_q2k100_rq10_ref1.5k_e151.pth'
output_path='results'
print(weight_file)
# Out:
# BC_q2k100_rq5_ref1.5k
# models/BC_q2k100_rq5_ref1.5k_e151.pth

# %%
DATA_PATH = '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/'

# %%
SZ=256
device='cuda'
train_csv=DATA_PATH+'/train.csv'
data_train = DATA_PATH
data_test  = DATA_PATH
data_type='normal'
normalize='imagenet'
N_TTA=0
part=0
n_part=1

# %%
weight_file = Path(weight_file)
output_path = Path(output_path)
ensure_folder(output_path)

# %%
ref = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_img').glob('*/*.png'))]
aisle = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_38').glob('*/*.png'))]
# ref = aisle

proto_df = pd.DataFrame({'image_path' : [str(i) for i in ref], 'label' : [i.parent.name for i in ref]})
proto_df['type'] = 'reference'

# %%
# GP_df = pd.read_csv('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/Grocery_products/reference_metadata.csv')
# GP_df['type'] = 'reference'

# GP_df.columns = ['image_path', 'class', 'class_id', 'sub_class_label', 'label', 'num_Query_imgs', 'type']
# GP_df['image_path']= GP_df['image_path'].map(lambda x: '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/Grocery_products/'+x)

# GP_df = GP_df[['image_path', 'label', 'type']]

# proto_df = proto_df.append(GP_df, ignore_index=True)

# %%
le = LabelEncoder()
proto_df['label_id'] = le.fit_transform(proto_df.label)

proto_df.head()
# Out:
#                                           image_path     label       type  \
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  50038959  reference
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  53425502  reference
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  31184578  reference
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  53132214  reference
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  53050477  reference
#
#    label_id
# 0       515
# 1       818
# 2       276
# 3       762
# 4       715

# %%
query_df = pd.read_csv('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/img_to_labels.csv', index_col=0)

query_df.columns = ['image_path', 'label']

query_df['image_path'] = query_df.image_path.map(lambda x : '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/' + x)

item_mapping = {'1' : '54629736', '2' : '54481233', '3' : '3572171', '4' : '5558787', '5' : '4810550', '6' : '29566609', '7' : '100000000', '8':'4810554', '9' :'23296492','10':'22965966','11' :'100000010', '12' : '53798269', '13' : '100000001', '14':'5186005','15' :'23296489', '16':'38957303','17':'37989538', '18' :'5401467', '19' :'4385267', '20':'5142520','21':'53419173','22':'54747442','23':'53197162','24':'5262834','25':'54217299','26':'42430527','27':'6986914','28':'50563145','29':'100000003','30':'53564608','31':'100000004','32':'100000005','33':'100000006','34':'54271401','35':'100000007','36':'53621633','37':'53798262','38':'31525622','39':'53537941','40':'54739328','41':'52867343','42':'54003387','43':'54565142'}
remove_lst = ['junk', '1', '7', '13', '29', '31', '32', '33', '35', '11']

query_df = query_df[-query_df.label.isin(remove_lst)].reset_index(drop=True)

query_df['label'] = query_df.label.map(lambda x : item_mapping[x])

query_df['type'] = 'query'
query_df['label_id'] = le.transform(query_df.label.values)

query_df.head()
# Out:
#                                           image_path    label   type  label_id
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query      1410

# %%
query_df['split'] = 'valid'
query_df.loc[query_df.image_path.isin(trn_qimgs), 'split'] = 'train'

# %%
query_df.split.value_counts()
# Out:
# valid    1506
# train     170
# Name: split, dtype: int64

# %%
data_train = '/'

# %%
print(f'Test samples: {len(query_df)}.')

# Making dataloaders
def get_dl(df, folder, SZ=SZ, batch_size=256, augment='test', normalize='imagenet'):
    if data_type == 'normal':
        ds = GrocerImages_plus(folder, df, re_size=SZ, to_size=SZ,
                             augment=augment, normalize=normalize, part=part, n_part=n_part)
    else:
        raise ValueError('invalid data type')
    dl = DataLoader(ds, batch_size=batch_size, shuffle=False, num_workers=8)
    return dl

# 1. NORMAL RESULT
# Make prototypes
trn_dl = get_dl(proto_df, data_train)
# model = feature_model
model = get_model_fn(device=device, weight_file=weight_file)
proto_net = ExtModelProtoNetClf(model, trn_dl.dataset.classes, device)
proto_net.make_prototypes(trn_dl)
# Out:
# Test samples: 1676.
#   0%|          | 0/37 [00:00<?, ?it/s]
#   3%|▎         | 1/37 [00:04<02:52,  4.79s/it]
#   5%|▌         | 2/37 [00:06<02:10,  3.74s/it]
#   8%|▊         | 3/37 [00:06<01:32,  2.73s/it]
#  11%|█         | 4/37 [00:06<01:06,  2.00s/it]
#  14%|█▎        | 5/37 [00:07<00:48,  1.51s/it]
#  16%|█▌        | 6/37 [00:07<00:35,  1.15s/it]
#  19%|█▉        | 7/37 [00:07<00:27,  1.09it/s]
#  22%|██▏       | 8/37 [00:08<00:21,  1.36it/s]
#  24%|██▍       | 9/37 [00:08<00:17,  1.56it/s]
#  27%|██▋       | 10/37 [00:09<00:19,  1.38it/s]
#  30%|██▉       | 11/37 [00:09<00:15,  1.63it/s]
#  32%|███▏      | 12/37 [00:10<00:12,  1.93it/s]
#  35%|███▌      | 13/37 [00:10<00:11,  2.09it/s]
#  38%|███▊      | 14/37 [00:10<00:09,  2.33it/s]
#  41%|████      | 15/37 [00:11<00:09,  2.38it/s]
#  43%|████▎     | 16/37 [00:11<00:08,  2.62it/s]
#  46%|████▌     | 17/37 [00:11<00:07,  2.65it/s]
#  49%|████▊     | 18/37 [00:13<00:12,  1.55it/s]
#  51%|█████▏    | 19/37 [00:13<00:10,  1.74it/s]
#  54%|█████▍    | 20/37 [00:13<00:08,  2.03it/s]
#  57%|█████▋    | 21/37 [00:14<00:07,  2.20it/s]
#  59%|█████▉    | 22/37 [00:14<00:06,  2.35it/s]
#  62%|██████▏   | 23/37 [00:15<00:05,  2.35it/s]
#  65%|██████▍   | 24/37 [00:15<00:05,  2.60it/s]
#  68%|██████▊   | 25/37 [00:15<00:04,  2.53it/s]
#  70%|███████   | 26/37 [00:16<00:05,  1.90it/s]
#  73%|███████▎  | 27/37 [00:16<00:04,  2.09it/s]
#  76%|███████▌  | 28/37 [00:17<00:03,  2.36it/s]
#  78%|███████▊  | 29/37 [00:17<00:03,  2.47it/s]
#  81%|████████  | 30/37 [00:17<00:02,  2.68it/s]
#  84%|████████▍ | 31/37 [00:18<00:02,  2.76it/s]
#  86%|████████▋ | 32/37 [00:18<00:01,  2.95it/s]
#  89%|████████▉ | 33/37 [00:18<00:01,  2.94it/s]
#  92%|█████████▏| 34/37 [00:19<00:00,  3.09it/s]
#  95%|█████████▍| 35/37 [00:19<00:00,  3.05it/s]
#  97%|█████████▋| 36/37 [00:19<00:00,  3.18it/s]
# 100%|██████████| 37/37 [00:19<00:00,  3.49it/s]
# 2020-04-24 05:42:41,048 dlcliche.utils make_prototypes [INFO]: Making new prototypes.

# %%
data_test='/'

# %%
# Calculate distances
test_dl = get_dl(query_df, data_test, batch_size=256)
test_embs, gts = proto_net.get_embeddings(test_dl)
test_dists = proto_net.predict_embeddings(test_embs, softmax=False) #Distance are already negated so dist shub b high now
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#  14%|█▍        | 1/7 [00:04<00:24,  4.08s/it]
#  29%|██▊       | 2/7 [00:04<00:14,  2.94s/it]
#  43%|████▎     | 3/7 [00:04<00:08,  2.16s/it]
#  57%|█████▋    | 4/7 [00:04<00:04,  1.60s/it]
#  71%|███████▏  | 5/7 [00:05<00:02,  1.22s/it]
#  86%|████████▌ | 6/7 [00:05<00:00,  1.07it/s]
# 100%|██████████| 7/7 [00:05<00:00,  1.39it/s]
#
#   0%|          | 0/1676 [00:00<?, ?it/s]
#   0%|          | 2/1676 [00:00<01:47, 15.62it/s]
#   0%|          | 4/1676 [00:00<01:47, 15.59it/s]
#   0%|          | 6/1676 [00:00<01:47, 15.56it/s]
#   0%|          | 8/1676 [00:00<01:47, 15.46it/s]
#   1%|          | 10/1676 [00:00<01:47, 15.49it/s]
#   1%|          | 12/1676 [00:00<01:47, 15.49it/s]
#   1%|          | 14/1676 [00:00<01:46, 15.54it/s]
#   1%|          | 16/1676 [00:01<01:46, 15.52it/s]
#   1%|          | 18/1676 [00:01<01:56, 14.28it/s]
#   1%|          | 20/1676 [00:01<01:53, 14.64it/s]
#   1%|▏         | 22/1676 [00:01<01:57, 14.02it/s]
#   1%|▏         | 24/1676 [00:01<01:58, 13.95it/s]
#   2%|▏         | 26/1676 [00:01<01:54, 14.39it/s]
#   2%|▏         | 28/1676 [00:01<01:51, 14.74it/s]
#   2%|▏         | 30/1676 [00:02<01:50, 14.93it/s]
#   2%|▏         | 32/1676 [00:02<01:48, 15.13it/s]
#   2%|▏         | 34/1676 [00:02<01:46, 15.38it/s]
#   2%|▏         | 36/1676 [00:02<01:45, 15.50it/s]
#   2%|▏         | 38/1676 [00:02<01:45, 15.54it/s]
#   2%|▏         | 40/1676 [00:02<01:48, 15.11it/s]
#   3%|▎         | 42/1676 [00:02<01:47, 15.21it/s]
#   3%|▎         | 44/1676 [00:02<01:46, 15.34it/s]
#   3%|▎         | 46/1676 [00:03<01:44, 15.52it/s]
#   3%|▎         | 48/1676 [00:03<01:44, 15.56it/s]
#   3%|▎         | 50/1676 [00:03<01:44, 15.58it/s]
#   3%|▎         | 52/1676 [00:03<01:43, 15.67it/s]
#   3%|▎         | 54/1676 [00:03<01:47, 15.04it/s]
#   3%|▎         | 56/1676 [00:03<01:47, 15.11it/s]
#   3%|▎         | 58/1676 [00:03<01:51, 14.47it/s]
#   4%|▎         | 60/1676 [00:04<01:56, 13.93it/s]
#   4%|▎         | 62/1676 [00:04<01:51, 14.48it/s]
#   4%|▍         | 64/1676 [00:04<01:49, 14.71it/s]
#   4%|▍         | 66/1676 [00:04<01:47, 14.96it/s]
#   4%|▍         | 68/1676 [00:04<01:47, 14.96it/s]
#   4%|▍         | 70/1676 [00:04<01:45, 15.18it/s]
#   4%|▍         | 72/1676 [00:04<01:45, 15.17it/s]
#   4%|▍         | 74/1676 [00:04<01:45, 15.24it/s]
#   5%|▍         | 76/1676 [00:05<01:43, 15.39it/s]
#   5%|▍         | 78/1676 [00:05<01:43, 15.51it/s]
#   5%|▍         | 80/1676 [00:05<01:43, 15.40it/s]
#   5%|▍         | 82/1676 [00:05<01:43, 15.35it/s]
#   5%|▌         | 84/1676 [00:05<01:48, 14.72it/s]
#   5%|▌         | 86/1676 [00:05<01:45, 15.03it/s]
#   5%|▌         | 88/1676 [00:05<01:45, 15.11it/s]
#   5%|▌         | 90/1676 [00:05<01:44, 15.18it/s]
#   5%|▌         | 92/1676 [00:06<01:43, 15.29it/s]
#   6%|▌         | 94/1676 [00:06<01:51, 14.13it/s]
#   6%|▌         | 96/1676 [00:06<01:49, 14.41it/s]
#   6%|▌         | 98/1676 [00:06<01:55, 13.60it/s]
#   6%|▌         | 100/1676 [00:06<01:50, 14.24it/s]
#   6%|▌         | 102/1676 [00:06<01:47, 14.63it/s]
#   6%|▌         | 104/1676 [00:06<01:48, 14.44it/s]
#   6%|▋         | 106/1676 [00:07<01:45, 14.82it/s]
#   6%|▋         | 108/1676 [00:07<01:46, 14.73it/s]
#   7%|▋         | 110/1676 [00:07<01:53, 13.77it/s]
#   7%|▋         | 112/1676 [00:07<01:50, 14.17it/s]
#   7%|▋         | 114/1676 [00:07<01:46, 14.61it/s]
#   7%|▋         | 116/1676 [00:07<01:44, 14.93it/s]
#   7%|▋         | 118/1676 [00:07<01:43, 15.06it/s]
#   7%|▋         | 120/1676 [00:08<01:42, 15.15it/s]
#   7%|▋         | 122/1676 [00:08<01:49, 14.23it/s]
#   7%|▋         | 124/1676 [00:08<01:55, 13.49it/s]
#   8%|▊         | 126/1676 [00:08<01:55, 13.44it/s]
#   8%|▊         | 128/1676 [00:08<01:50, 14.06it/s]
#   8%|▊         | 130/1676 [00:08<01:46, 14.46it/s]
#   8%|▊         | 132/1676 [00:08<01:44, 14.83it/s]
#   8%|▊         | 134/1676 [00:09<01:48, 14.22it/s]
#   8%|▊         | 136/1676 [00:09<01:46, 14.51it/s]
#   8%|▊         | 138/1676 [00:09<01:43, 14.84it/s]
#   8%|▊         | 140/1676 [00:09<01:41, 15.08it/s]
#   8%|▊         | 142/1676 [00:09<01:42, 14.98it/s]
#   9%|▊         | 144/1676 [00:09<01:45, 14.47it/s]
#   9%|▊         | 146/1676 [00:09<01:43, 14.77it/s]
#   9%|▉         | 148/1676 [00:09<01:41, 15.01it/s]
#   9%|▉         | 150/1676 [00:10<01:40, 15.17it/s]
#   9%|▉         | 152/1676 [00:10<01:43, 14.76it/s]
#   9%|▉         | 154/1676 [00:10<01:41, 15.01it/s]
#   9%|▉         | 156/1676 [00:10<01:39, 15.28it/s]
#   9%|▉         | 158/1676 [00:10<01:38, 15.36it/s]
#  10%|▉         | 160/1676 [00:10<01:37, 15.47it/s]
#  10%|▉         | 162/1676 [00:10<01:37, 15.54it/s]
#  10%|▉         | 164/1676 [00:11<01:37, 15.54it/s]
#  10%|▉         | 166/1676 [00:11<01:41, 14.88it/s]
#  10%|█         | 168/1676 [00:11<01:44, 14.45it/s]
#  10%|█         | 170/1676 [00:11<01:46, 14.11it/s]
#  10%|█         | 172/1676 [00:11<01:43, 14.52it/s]
#  10%|█         | 174/1676 [00:11<01:41, 14.83it/s]
#  11%|█         | 176/1676 [00:11<01:39, 15.09it/s]
#  11%|█         | 178/1676 [00:11<01:38, 15.28it/s]
#  11%|█         | 180/1676 [00:12<01:36, 15.46it/s]
#  11%|█         | 182/1676 [00:12<01:39, 14.97it/s]
#  11%|█         | 184/1676 [00:12<01:38, 15.08it/s]
#  11%|█         | 186/1676 [00:12<01:37, 15.22it/s]
#  11%|█         | 188/1676 [00:12<01:37, 15.31it/s]
#  11%|█▏        | 190/1676 [00:12<01:36, 15.32it/s]
#  11%|█▏        | 192/1676 [00:12<01:36, 15.42it/s]
#  12%|█▏        | 194/1676 [00:13<01:35, 15.50it/s]
#  12%|█▏        | 196/1676 [00:13<01:34, 15.60it/s]
#  12%|█▏        | 198/1676 [00:13<01:34, 15.59it/s]
#  12%|█▏        | 200/1676 [00:13<01:35, 15.53it/s]
#  12%|█▏        | 202/1676 [00:13<01:34, 15.67it/s]
#  12%|█▏        | 204/1676 [00:13<01:33, 15.70it/s]
#  12%|█▏        | 206/1676 [00:13<01:33, 15.79it/s]
#  12%|█▏        | 208/1676 [00:13<01:41, 14.40it/s]
#  13%|█▎        | 210/1676 [00:14<01:39, 14.68it/s]
#  13%|█▎        | 212/1676 [00:14<01:37, 14.97it/s]
#  13%|█▎        | 214/1676 [00:14<01:37, 15.05it/s]
#  13%|█▎        | 216/1676 [00:14<01:38, 14.76it/s]
#  13%|█▎        | 218/1676 [00:14<01:42, 14.18it/s]
#  13%|█▎        | 220/1676 [00:14<01:39, 14.69it/s]
#  13%|█▎        | 222/1676 [00:14<01:37, 14.95it/s]
#  13%|█▎        | 224/1676 [00:15<01:35, 15.15it/s]
#  13%|█▎        | 226/1676 [00:15<01:34, 15.32it/s]
#  14%|█▎        | 228/1676 [00:15<01:33, 15.46it/s]
#  14%|█▎        | 230/1676 [00:15<01:37, 14.80it/s]
#  14%|█▍        | 232/1676 [00:15<01:37, 14.80it/s]
#  14%|█▍        | 234/1676 [00:15<01:36, 14.96it/s]
#  14%|█▍        | 236/1676 [00:15<01:35, 15.11it/s]
#  14%|█▍        | 238/1676 [00:15<01:34, 15.25it/s]
#  14%|█▍        | 240/1676 [00:16<01:33, 15.38it/s]
#  14%|█▍        | 242/1676 [00:16<01:32, 15.49it/s]
#  15%|█▍        | 244/1676 [00:16<01:41, 14.17it/s]
#  15%|█▍        | 246/1676 [00:16<01:41, 14.10it/s]
#  15%|█▍        | 248/1676 [00:16<01:38, 14.46it/s]
#  15%|█▍        | 250/1676 [00:16<01:41, 14.10it/s]
#  15%|█▌        | 252/1676 [00:16<01:37, 14.58it/s]
#  15%|█▌        | 254/1676 [00:17<01:35, 14.84it/s]
#  15%|█▌        | 256/1676 [00:17<01:34, 15.09it/s]
#  15%|█▌        | 258/1676 [00:17<01:40, 14.04it/s]
#  16%|█▌        | 260/1676 [00:17<01:42, 13.82it/s]
#  16%|█▌        | 262/1676 [00:17<01:39, 14.28it/s]
#  16%|█▌        | 264/1676 [00:17<01:36, 14.65it/s]
#  16%|█▌        | 266/1676 [00:17<01:39, 14.13it/s]
#  16%|█▌        | 268/1676 [00:18<01:43, 13.56it/s]
#  16%|█▌        | 270/1676 [00:18<01:41, 13.91it/s]
#  16%|█▌        | 272/1676 [00:18<01:37, 14.36it/s]
#  16%|█▋        | 274/1676 [00:18<01:34, 14.76it/s]
#  16%|█▋        | 276/1676 [00:18<01:33, 14.95it/s]
#  17%|█▋        | 278/1676 [00:18<01:33, 14.94it/s]
#  17%|█▋        | 280/1676 [00:18<01:38, 14.11it/s]
#  17%|█▋        | 282/1676 [00:19<01:42, 13.58it/s]
#  17%|█▋        | 284/1676 [00:19<01:46, 13.05it/s]
#  17%|█▋        | 286/1676 [00:19<01:49, 12.70it/s]
#  17%|█▋        | 288/1676 [00:19<01:45, 13.13it/s]
#  17%|█▋        | 290/1676 [00:19<01:40, 13.73it/s]
#  17%|█▋        | 292/1676 [00:19<01:37, 14.15it/s]
#  18%|█▊        | 294/1676 [00:19<01:34, 14.59it/s]
#  18%|█▊        | 296/1676 [00:20<01:32, 14.91it/s]
#  18%|█▊        | 298/1676 [00:20<01:30, 15.17it/s]
#  18%|█▊        | 300/1676 [00:20<01:38, 13.99it/s]
#  18%|█▊        | 302/1676 [00:20<01:43, 13.25it/s]
#  18%|█▊        | 304/1676 [00:20<01:43, 13.23it/s]
#  18%|█▊        | 306/1676 [00:20<01:38, 13.87it/s]
#  18%|█▊        | 308/1676 [00:20<01:35, 14.30it/s]
#  18%|█▊        | 310/1676 [00:21<01:35, 14.25it/s]
#  19%|█▊        | 312/1676 [00:21<01:40, 13.52it/s]
#  19%|█▊        | 314/1676 [00:21<01:44, 13.04it/s]
#  19%|█▉        | 316/1676 [00:21<01:47, 12.64it/s]
#  19%|█▉        | 318/1676 [00:21<01:43, 13.16it/s]
#  19%|█▉        | 320/1676 [00:21<01:38, 13.73it/s]
#  19%|█▉        | 322/1676 [00:21<01:35, 14.18it/s]
#  19%|█▉        | 324/1676 [00:22<01:37, 13.89it/s]
#  19%|█▉        | 326/1676 [00:22<01:33, 14.46it/s]
#  20%|█▉        | 328/1676 [00:22<01:31, 14.80it/s]
#  20%|█▉        | 330/1676 [00:22<01:29, 15.08it/s]
#  20%|█▉        | 332/1676 [00:22<01:28, 15.27it/s]
#  20%|█▉        | 334/1676 [00:22<01:26, 15.43it/s]
#  20%|██        | 336/1676 [00:22<01:27, 15.38it/s]
#  20%|██        | 338/1676 [00:23<01:34, 14.22it/s]
#  20%|██        | 340/1676 [00:23<01:35, 14.01it/s]
#  20%|██        | 342/1676 [00:23<01:32, 14.50it/s]
#  21%|██        | 344/1676 [00:23<01:33, 14.20it/s]
#  21%|██        | 346/1676 [00:23<01:30, 14.62it/s]
#  21%|██        | 348/1676 [00:23<01:28, 14.93it/s]
#  21%|██        | 350/1676 [00:23<01:28, 15.06it/s]
#  21%|██        | 352/1676 [00:23<01:29, 14.85it/s]
#  21%|██        | 354/1676 [00:24<01:28, 14.91it/s]
#  21%|██        | 356/1676 [00:24<01:28, 14.85it/s]
#  21%|██▏       | 358/1676 [00:24<01:34, 13.98it/s]
#  21%|██▏       | 360/1676 [00:24<01:30, 14.48it/s]
#  22%|██▏       | 362/1676 [00:24<01:29, 14.64it/s]
#  22%|██▏       | 364/1676 [00:24<01:27, 15.01it/s]
#  22%|██▏       | 366/1676 [00:24<01:28, 14.85it/s]
#  22%|██▏       | 368/1676 [00:25<01:28, 14.80it/s]
#  22%|██▏       | 370/1676 [00:25<01:26, 15.12it/s]
#  22%|██▏       | 372/1676 [00:25<01:25, 15.25it/s]
#  22%|██▏       | 374/1676 [00:25<01:24, 15.38it/s]
#  22%|██▏       | 376/1676 [00:25<01:31, 14.22it/s]
#  23%|██▎       | 378/1676 [00:25<01:28, 14.68it/s]
#  23%|██▎       | 380/1676 [00:25<01:26, 14.95it/s]
#  23%|██▎       | 382/1676 [00:25<01:28, 14.61it/s]
#  23%|██▎       | 384/1676 [00:26<01:31, 14.10it/s]
#  23%|██▎       | 386/1676 [00:26<01:28, 14.55it/s]
#  23%|██▎       | 388/1676 [00:26<01:28, 14.59it/s]
#  23%|██▎       | 390/1676 [00:26<01:29, 14.41it/s]
#  23%|██▎       | 392/1676 [00:26<01:27, 14.73it/s]
#  24%|██▎       | 394/1676 [00:26<01:25, 15.04it/s]
#  24%|██▎       | 396/1676 [00:26<01:23, 15.29it/s]
#  24%|██▎       | 398/1676 [00:27<01:23, 15.39it/s]
#  24%|██▍       | 400/1676 [00:27<01:23, 15.33it/s]
#  24%|██▍       | 402/1676 [00:27<01:25, 14.98it/s]
#  24%|██▍       | 404/1676 [00:27<01:23, 15.17it/s]
#  24%|██▍       | 406/1676 [00:27<01:22, 15.30it/s]
#  24%|██▍       | 408/1676 [00:27<01:22, 15.44it/s]
#  24%|██▍       | 410/1676 [00:27<01:21, 15.51it/s]
#  25%|██▍       | 412/1676 [00:27<01:21, 15.52it/s]
#  25%|██▍       | 414/1676 [00:28<01:21, 15.52it/s]
#  25%|██▍       | 416/1676 [00:28<01:23, 15.12it/s]
#  25%|██▍       | 418/1676 [00:28<01:22, 15.27it/s]
#  25%|██▌       | 420/1676 [00:28<01:23, 15.09it/s]
#  25%|██▌       | 422/1676 [00:28<01:22, 15.15it/s]
#  25%|██▌       | 424/1676 [00:28<01:21, 15.29it/s]
#  25%|██▌       | 426/1676 [00:28<01:21, 15.42it/s]
#  26%|██▌       | 428/1676 [00:29<01:20, 15.51it/s]
#  26%|██▌       | 430/1676 [00:29<01:20, 15.57it/s]
#  26%|██▌       | 432/1676 [00:29<01:19, 15.57it/s]
#  26%|██▌       | 434/1676 [00:29<01:19, 15.56it/s]
#  26%|██▌       | 436/1676 [00:29<01:19, 15.61it/s]
#  26%|██▌       | 438/1676 [00:29<01:21, 15.27it/s]
#  26%|██▋       | 440/1676 [00:29<01:20, 15.40it/s]
#  26%|██▋       | 442/1676 [00:29<01:19, 15.49it/s]
#  26%|██▋       | 444/1676 [00:30<01:19, 15.55it/s]
#  27%|██▋       | 446/1676 [00:30<01:18, 15.64it/s]
#  27%|██▋       | 448/1676 [00:30<01:23, 14.76it/s]
#  27%|██▋       | 450/1676 [00:30<01:21, 15.06it/s]
#  27%|██▋       | 452/1676 [00:30<01:20, 15.29it/s]
#  27%|██▋       | 454/1676 [00:30<01:19, 15.43it/s]
#  27%|██▋       | 456/1676 [00:30<01:23, 14.65it/s]
#  27%|██▋       | 458/1676 [00:31<01:28, 13.73it/s]
#  27%|██▋       | 460/1676 [00:31<01:32, 13.12it/s]
#  28%|██▊       | 462/1676 [00:31<01:31, 13.26it/s]
#  28%|██▊       | 464/1676 [00:31<01:30, 13.42it/s]
#  28%|██▊       | 466/1676 [00:31<01:30, 13.41it/s]
#  28%|██▊       | 468/1676 [00:31<01:25, 14.10it/s]
#  28%|██▊       | 470/1676 [00:31<01:22, 14.55it/s]
#  28%|██▊       | 472/1676 [00:32<01:20, 14.93it/s]
#  28%|██▊       | 474/1676 [00:32<01:18, 15.23it/s]
#  28%|██▊       | 476/1676 [00:32<01:17, 15.43it/s]
#  29%|██▊       | 478/1676 [00:32<01:22, 14.52it/s]
#  29%|██▊       | 480/1676 [00:32<01:23, 14.29it/s]
#  29%|██▉       | 482/1676 [00:32<01:22, 14.54it/s]
#  29%|██▉       | 484/1676 [00:32<01:20, 14.88it/s]
#  29%|██▉       | 486/1676 [00:32<01:18, 15.07it/s]
#  29%|██▉       | 488/1676 [00:33<01:17, 15.27it/s]
#  29%|██▉       | 490/1676 [00:33<01:16, 15.45it/s]
#  29%|██▉       | 492/1676 [00:33<01:16, 15.55it/s]
#  29%|██▉       | 494/1676 [00:33<01:18, 15.09it/s]
#  30%|██▉       | 496/1676 [00:33<01:18, 14.97it/s]
#  30%|██▉       | 498/1676 [00:33<01:18, 15.03it/s]
#  30%|██▉       | 500/1676 [00:33<01:17, 15.25it/s]
#  30%|██▉       | 502/1676 [00:34<01:19, 14.81it/s]
#  30%|███       | 504/1676 [00:34<01:24, 13.89it/s]
#  30%|███       | 506/1676 [00:34<01:28, 13.21it/s]
#  30%|███       | 508/1676 [00:34<01:27, 13.34it/s]
#  30%|███       | 510/1676 [00:34<01:24, 13.86it/s]
#  31%|███       | 512/1676 [00:34<01:21, 14.36it/s]
#  31%|███       | 514/1676 [00:34<01:19, 14.62it/s]
#  31%|███       | 516/1676 [00:35<01:22, 14.03it/s]
#  31%|███       | 518/1676 [00:35<01:26, 13.38it/s]
#  31%|███       | 520/1676 [00:35<01:29, 12.89it/s]
#  31%|███       | 522/1676 [00:35<01:26, 13.41it/s]
#  31%|███▏      | 524/1676 [00:35<01:22, 13.90it/s]
#  31%|███▏      | 526/1676 [00:35<01:20, 14.30it/s]
#  32%|███▏      | 528/1676 [00:35<01:18, 14.55it/s]
#  32%|███▏      | 530/1676 [00:36<01:16, 14.90it/s]
#  32%|███▏      | 532/1676 [00:36<01:20, 14.24it/s]
#  32%|███▏      | 534/1676 [00:36<01:18, 14.62it/s]
#  32%|███▏      | 536/1676 [00:36<01:16, 14.93it/s]
#  32%|███▏      | 538/1676 [00:36<01:15, 15.09it/s]
#  32%|███▏      | 540/1676 [00:36<01:18, 14.45it/s]
#  32%|███▏      | 542/1676 [00:36<01:23, 13.58it/s]
#  32%|███▏      | 544/1676 [00:37<01:27, 13.01it/s]
#  33%|███▎      | 546/1676 [00:37<01:23, 13.55it/s]
#  33%|███▎      | 548/1676 [00:37<01:23, 13.48it/s]
#  33%|███▎      | 550/1676 [00:37<01:22, 13.62it/s]
#  33%|███▎      | 552/1676 [00:37<01:24, 13.29it/s]
#  33%|███▎      | 554/1676 [00:37<01:23, 13.50it/s]
#  33%|███▎      | 556/1676 [00:37<01:19, 14.07it/s]
#  33%|███▎      | 558/1676 [00:38<01:17, 14.49it/s]
#  33%|███▎      | 560/1676 [00:38<01:15, 14.79it/s]
#  34%|███▎      | 562/1676 [00:38<01:14, 15.03it/s]
#  34%|███▎      | 564/1676 [00:38<01:13, 15.22it/s]
#  34%|███▍      | 566/1676 [00:38<01:12, 15.36it/s]
#  34%|███▍      | 568/1676 [00:38<01:12, 15.30it/s]
#  34%|███▍      | 570/1676 [00:38<01:15, 14.71it/s]
#  34%|███▍      | 572/1676 [00:38<01:13, 14.94it/s]
#  34%|███▍      | 574/1676 [00:39<01:15, 14.54it/s]
#  34%|███▍      | 576/1676 [00:39<01:20, 13.73it/s]
#  34%|███▍      | 578/1676 [00:39<01:17, 14.24it/s]
#  35%|███▍      | 580/1676 [00:39<01:14, 14.67it/s]
#  35%|███▍      | 582/1676 [00:39<01:13, 14.96it/s]
#  35%|███▍      | 584/1676 [00:39<01:18, 13.89it/s]
#  35%|███▍      | 586/1676 [00:39<01:18, 13.80it/s]
#  35%|███▌      | 588/1676 [00:40<01:21, 13.43it/s]
#  35%|███▌      | 590/1676 [00:40<01:17, 13.99it/s]
#  35%|███▌      | 592/1676 [00:40<01:15, 14.41it/s]
#  35%|███▌      | 594/1676 [00:40<01:13, 14.77it/s]
#  36%|███▌      | 596/1676 [00:40<01:11, 15.08it/s]
#  36%|███▌      | 598/1676 [00:40<01:10, 15.30it/s]
#  36%|███▌      | 600/1676 [00:40<01:10, 15.27it/s]
#  36%|███▌      | 602/1676 [00:41<01:10, 15.27it/s]
#  36%|███▌      | 604/1676 [00:41<01:09, 15.43it/s]
#  36%|███▌      | 606/1676 [00:41<01:09, 15.45it/s]
#  36%|███▋      | 608/1676 [00:41<01:08, 15.49it/s]
#  36%|███▋      | 610/1676 [00:41<01:08, 15.57it/s]
#  37%|███▋      | 612/1676 [00:41<01:08, 15.64it/s]
#  37%|███▋      | 614/1676 [00:41<01:07, 15.67it/s]
#  37%|███▋      | 616/1676 [00:41<01:11, 14.79it/s]
#  37%|███▋      | 618/1676 [00:42<01:12, 14.59it/s]
#  37%|███▋      | 620/1676 [00:42<01:11, 14.83it/s]
#  37%|███▋      | 622/1676 [00:42<01:09, 15.08it/s]
#  37%|███▋      | 624/1676 [00:42<01:09, 15.18it/s]
#  37%|███▋      | 626/1676 [00:42<01:08, 15.35it/s]
#  37%|███▋      | 628/1676 [00:42<01:12, 14.45it/s]
#  38%|███▊      | 630/1676 [00:42<01:16, 13.58it/s]
#  38%|███▊      | 632/1676 [00:43<01:19, 13.17it/s]
#  38%|███▊      | 634/1676 [00:43<01:15, 13.86it/s]
#  38%|███▊      | 636/1676 [00:43<01:15, 13.76it/s]
#  38%|███▊      | 638/1676 [00:43<01:15, 13.69it/s]
#  38%|███▊      | 640/1676 [00:43<01:12, 14.25it/s]
#  38%|███▊      | 642/1676 [00:43<01:10, 14.74it/s]
#  38%|███▊      | 644/1676 [00:43<01:08, 15.00it/s]
#  39%|███▊      | 646/1676 [00:44<01:07, 15.22it/s]
#  39%|███▊      | 648/1676 [00:44<01:09, 14.72it/s]
#  39%|███▉      | 650/1676 [00:44<01:08, 15.02it/s]
#  39%|███▉      | 652/1676 [00:44<01:09, 14.71it/s]
#  39%|███▉      | 654/1676 [00:44<01:08, 14.93it/s]
#  39%|███▉      | 656/1676 [00:44<01:09, 14.69it/s]
#  39%|███▉      | 658/1676 [00:44<01:08, 14.97it/s]
#  39%|███▉      | 660/1676 [00:44<01:06, 15.22it/s]
#  39%|███▉      | 662/1676 [00:45<01:06, 15.31it/s]
#  40%|███▉      | 664/1676 [00:45<01:06, 15.26it/s]
#  40%|███▉      | 666/1676 [00:45<01:11, 14.08it/s]
#  40%|███▉      | 668/1676 [00:45<01:09, 14.44it/s]
#  40%|███▉      | 670/1676 [00:45<01:11, 14.05it/s]
#  40%|████      | 672/1676 [00:45<01:15, 13.33it/s]
#  40%|████      | 674/1676 [00:45<01:12, 13.91it/s]
#  40%|████      | 676/1676 [00:46<01:09, 14.43it/s]
#  40%|████      | 678/1676 [00:46<01:08, 14.53it/s]
#  41%|████      | 680/1676 [00:46<01:07, 14.84it/s]
#  41%|████      | 682/1676 [00:46<01:05, 15.09it/s]
#  41%|████      | 684/1676 [00:46<01:04, 15.29it/s]
#  41%|████      | 686/1676 [00:46<01:03, 15.47it/s]
#  41%|████      | 688/1676 [00:46<01:03, 15.58it/s]
#  41%|████      | 690/1676 [00:46<01:02, 15.67it/s]
#  41%|████▏     | 692/1676 [00:47<01:02, 15.71it/s]
#  41%|████▏     | 694/1676 [00:47<01:05, 14.89it/s]
#  42%|████▏     | 696/1676 [00:47<01:10, 13.89it/s]
#  42%|████▏     | 698/1676 [00:47<01:12, 13.55it/s]
#  42%|████▏     | 700/1676 [00:47<01:09, 14.13it/s]
#  42%|████▏     | 702/1676 [00:47<01:07, 14.52it/s]
#  42%|████▏     | 704/1676 [00:47<01:05, 14.89it/s]
#  42%|████▏     | 706/1676 [00:48<01:05, 14.78it/s]
#  42%|████▏     | 708/1676 [00:48<01:06, 14.57it/s]
#  42%|████▏     | 710/1676 [00:48<01:07, 14.33it/s]
#  42%|████▏     | 712/1676 [00:48<01:05, 14.67it/s]
#  43%|████▎     | 714/1676 [00:48<01:04, 14.80it/s]
#  43%|████▎     | 716/1676 [00:48<01:03, 15.11it/s]
#  43%|████▎     | 718/1676 [00:48<01:02, 15.27it/s]
#  43%|████▎     | 720/1676 [00:49<01:02, 15.42it/s]
#  43%|████▎     | 722/1676 [00:49<01:01, 15.51it/s]
#  43%|████▎     | 724/1676 [00:49<01:01, 15.53it/s]
#  43%|████▎     | 726/1676 [00:49<01:01, 15.42it/s]
#  43%|████▎     | 728/1676 [00:49<01:01, 15.45it/s]
#  44%|████▎     | 730/1676 [00:49<01:01, 15.42it/s]
#  44%|████▎     | 732/1676 [00:49<01:00, 15.57it/s]
#  44%|████▍     | 734/1676 [00:49<01:03, 14.95it/s]
#  44%|████▍     | 736/1676 [00:50<01:07, 13.87it/s]
#  44%|████▍     | 738/1676 [00:50<01:10, 13.22it/s]
#  44%|████▍     | 740/1676 [00:50<01:09, 13.46it/s]
#  44%|████▍     | 742/1676 [00:50<01:07, 13.87it/s]
#  44%|████▍     | 744/1676 [00:50<01:04, 14.38it/s]
#  45%|████▍     | 746/1676 [00:50<01:07, 13.86it/s]
#  45%|████▍     | 748/1676 [00:51<01:07, 13.65it/s]
#  45%|████▍     | 750/1676 [00:51<01:04, 14.26it/s]
#  45%|████▍     | 752/1676 [00:51<01:02, 14.68it/s]
#  45%|████▍     | 754/1676 [00:51<01:01, 14.97it/s]
#  45%|████▌     | 756/1676 [00:51<01:01, 15.06it/s]
#  45%|████▌     | 758/1676 [00:51<01:02, 14.73it/s]
#  45%|████▌     | 760/1676 [00:51<01:05, 13.92it/s]
#  45%|████▌     | 762/1676 [00:51<01:09, 13.22it/s]
#  46%|████▌     | 764/1676 [00:52<01:06, 13.82it/s]
#  46%|████▌     | 766/1676 [00:52<01:03, 14.33it/s]
#  46%|████▌     | 768/1676 [00:52<01:01, 14.71it/s]
#  46%|████▌     | 770/1676 [00:52<01:00, 14.88it/s]
#  46%|████▌     | 772/1676 [00:52<01:00, 14.90it/s]
#  46%|████▌     | 774/1676 [00:52<00:59, 15.11it/s]
#  46%|████▋     | 776/1676 [00:52<00:58, 15.29it/s]
#  46%|████▋     | 778/1676 [00:53<00:58, 15.46it/s]
#  47%|████▋     | 780/1676 [00:53<00:57, 15.59it/s]
#  47%|████▋     | 782/1676 [00:53<00:56, 15.69it/s]
#  47%|████▋     | 784/1676 [00:53<00:58, 15.33it/s]
#  47%|████▋     | 786/1676 [00:53<00:57, 15.49it/s]
#  47%|████▋     | 788/1676 [00:53<00:57, 15.39it/s]
#  47%|████▋     | 790/1676 [00:53<00:57, 15.44it/s]
#  47%|████▋     | 792/1676 [00:53<01:00, 14.52it/s]
#  47%|████▋     | 794/1676 [00:54<01:00, 14.57it/s]
#  47%|████▋     | 796/1676 [00:54<01:00, 14.60it/s]
#  48%|████▊     | 798/1676 [00:54<00:59, 14.67it/s]
#  48%|████▊     | 800/1676 [00:54<00:58, 14.97it/s]
#  48%|████▊     | 802/1676 [00:54<01:00, 14.54it/s]
#  48%|████▊     | 804/1676 [00:54<01:00, 14.52it/s]
#  48%|████▊     | 806/1676 [00:54<00:59, 14.70it/s]
#  48%|████▊     | 808/1676 [00:55<00:57, 14.97it/s]
#  48%|████▊     | 810/1676 [00:55<00:56, 15.21it/s]
#  48%|████▊     | 812/1676 [00:55<00:56, 15.36it/s]
#  49%|████▊     | 814/1676 [00:55<00:55, 15.42it/s]
#  49%|████▊     | 816/1676 [00:55<00:55, 15.52it/s]
#  49%|████▉     | 818/1676 [00:55<00:55, 15.59it/s]
#  49%|████▉     | 820/1676 [00:55<00:57, 14.86it/s]
#  49%|████▉     | 822/1676 [00:55<00:56, 15.07it/s]
#  49%|████▉     | 824/1676 [00:56<00:55, 15.22it/s]
#  49%|████▉     | 826/1676 [00:56<00:55, 15.35it/s]
#  49%|████▉     | 828/1676 [00:56<00:55, 15.37it/s]
#  50%|████▉     | 830/1676 [00:56<00:56, 14.93it/s]
#  50%|████▉     | 832/1676 [00:56<00:56, 15.02it/s]
#  50%|████▉     | 834/1676 [00:56<00:55, 15.05it/s]
#  50%|████▉     | 836/1676 [00:56<00:57, 14.56it/s]
#  50%|█████     | 838/1676 [00:57<00:58, 14.25it/s]
#  50%|█████     | 840/1676 [00:57<00:57, 14.63it/s]
#  50%|█████     | 842/1676 [00:57<00:57, 14.42it/s]
#  50%|█████     | 844/1676 [00:57<00:56, 14.62it/s]
#  50%|█████     | 846/1676 [00:57<00:57, 14.47it/s]
#  51%|█████     | 848/1676 [00:57<00:55, 14.84it/s]
#  51%|█████     | 850/1676 [00:57<00:56, 14.61it/s]
#  51%|█████     | 852/1676 [00:58<00:59, 13.74it/s]
#  51%|█████     | 854/1676 [00:58<01:00, 13.66it/s]
#  51%|█████     | 856/1676 [00:58<00:57, 14.22it/s]
#  51%|█████     | 858/1676 [00:58<00:56, 14.58it/s]
#  51%|█████▏    | 860/1676 [00:58<00:54, 14.88it/s]
#  51%|█████▏    | 862/1676 [00:58<00:54, 14.93it/s]
#  52%|█████▏    | 864/1676 [00:58<00:53, 15.25it/s]
#  52%|█████▏    | 866/1676 [00:58<00:55, 14.60it/s]
#  52%|█████▏    | 868/1676 [00:59<00:58, 13.73it/s]
#  52%|█████▏    | 870/1676 [00:59<00:57, 13.97it/s]
#  52%|█████▏    | 872/1676 [00:59<01:00, 13.22it/s]
#  52%|█████▏    | 874/1676 [00:59<00:58, 13.68it/s]
#  52%|█████▏    | 876/1676 [00:59<00:56, 14.17it/s]
#  52%|█████▏    | 878/1676 [00:59<00:54, 14.52it/s]
#  53%|█████▎    | 880/1676 [00:59<00:53, 14.81it/s]
#  53%|█████▎    | 882/1676 [01:00<00:52, 14.99it/s]
#  53%|█████▎    | 884/1676 [01:00<00:52, 15.11it/s]
#  53%|█████▎    | 886/1676 [01:00<00:51, 15.25it/s]
#  53%|█████▎    | 888/1676 [01:00<00:51, 15.34it/s]
#  53%|█████▎    | 890/1676 [01:00<00:51, 15.41it/s]
#  53%|█████▎    | 892/1676 [01:00<00:55, 14.22it/s]
#  53%|█████▎    | 894/1676 [01:00<00:58, 13.42it/s]
#  53%|█████▎    | 896/1676 [01:01<01:00, 12.95it/s]
#  54%|█████▎    | 898/1676 [01:01<00:59, 13.08it/s]
#  54%|█████▎    | 900/1676 [01:01<00:57, 13.47it/s]
#  54%|█████▍    | 902/1676 [01:01<00:56, 13.74it/s]
#  54%|█████▍    | 904/1676 [01:01<00:54, 14.22it/s]
#  54%|█████▍    | 906/1676 [01:01<00:52, 14.64it/s]
#  54%|█████▍    | 908/1676 [01:01<00:51, 14.96it/s]
#  54%|█████▍    | 910/1676 [01:02<00:50, 15.17it/s]
#  54%|█████▍    | 912/1676 [01:02<00:53, 14.38it/s]
#  55%|█████▍    | 914/1676 [01:02<00:53, 14.36it/s]
#  55%|█████▍    | 916/1676 [01:02<00:51, 14.71it/s]
#  55%|█████▍    | 918/1676 [01:02<00:52, 14.42it/s]
#  55%|█████▍    | 920/1676 [01:02<00:51, 14.64it/s]
#  55%|█████▌    | 922/1676 [01:02<00:50, 14.92it/s]
#  55%|█████▌    | 924/1676 [01:02<00:49, 15.15it/s]
#  55%|█████▌    | 926/1676 [01:03<00:49, 15.25it/s]
#  55%|█████▌    | 928/1676 [01:03<00:48, 15.31it/s]
#  55%|█████▌    | 930/1676 [01:03<00:48, 15.34it/s]
#  56%|█████▌    | 932/1676 [01:03<00:48, 15.37it/s]
#  56%|█████▌    | 934/1676 [01:03<00:48, 15.40it/s]
#  56%|█████▌    | 936/1676 [01:03<00:47, 15.43it/s]
#  56%|█████▌    | 938/1676 [01:03<00:47, 15.51it/s]
#  56%|█████▌    | 940/1676 [01:04<00:47, 15.59it/s]
#  56%|█████▌    | 942/1676 [01:04<00:46, 15.64it/s]
#  56%|█████▋    | 944/1676 [01:04<00:49, 14.75it/s]
#  56%|█████▋    | 946/1676 [01:04<00:51, 14.05it/s]
#  57%|█████▋    | 948/1676 [01:04<00:51, 14.05it/s]
#  57%|█████▋    | 950/1676 [01:04<00:50, 14.36it/s]
#  57%|█████▋    | 952/1676 [01:04<00:53, 13.62it/s]
#  57%|█████▋    | 954/1676 [01:05<00:50, 14.18it/s]
#  57%|█████▋    | 956/1676 [01:05<00:49, 14.65it/s]
#  57%|█████▋    | 958/1676 [01:05<00:49, 14.42it/s]
#  57%|█████▋    | 960/1676 [01:05<00:50, 14.07it/s]
#  57%|█████▋    | 962/1676 [01:05<00:49, 14.52it/s]
#  58%|█████▊    | 964/1676 [01:05<00:47, 14.88it/s]
#  58%|█████▊    | 966/1676 [01:05<00:46, 15.11it/s]
#  58%|█████▊    | 968/1676 [01:05<00:46, 15.30it/s]
#  58%|█████▊    | 970/1676 [01:06<00:45, 15.43it/s]
#  58%|█████▊    | 972/1676 [01:06<00:45, 15.58it/s]
#  58%|█████▊    | 974/1676 [01:06<00:45, 15.55it/s]
#  58%|█████▊    | 976/1676 [01:06<00:45, 15.30it/s]
#  58%|█████▊    | 978/1676 [01:06<00:47, 14.66it/s]
#  58%|█████▊    | 980/1676 [01:06<00:50, 13.81it/s]
#  59%|█████▊    | 982/1676 [01:06<00:49, 13.94it/s]
#  59%|█████▊    | 984/1676 [01:07<00:47, 14.45it/s]
#  59%|█████▉    | 986/1676 [01:07<00:47, 14.59it/s]
#  59%|█████▉    | 988/1676 [01:07<00:49, 13.98it/s]
#  59%|█████▉    | 990/1676 [01:07<00:50, 13.51it/s]
#  59%|█████▉    | 992/1676 [01:07<00:50, 13.61it/s]
#  59%|█████▉    | 994/1676 [01:07<00:48, 14.16it/s]
#  59%|█████▉    | 996/1676 [01:07<00:46, 14.60it/s]
#  60%|█████▉    | 998/1676 [01:08<00:48, 13.91it/s]
#  60%|█████▉    | 1000/1676 [01:08<00:51, 13.23it/s]
#  60%|█████▉    | 1002/1676 [01:08<00:52, 12.79it/s]
#  60%|█████▉    | 1004/1676 [01:08<00:52, 12.85it/s]
#  60%|██████    | 1006/1676 [01:08<00:49, 13.57it/s]
#  60%|██████    | 1008/1676 [01:08<00:47, 14.16it/s]
#  60%|██████    | 1010/1676 [01:08<00:45, 14.62it/s]
#  60%|██████    | 1012/1676 [01:09<00:44, 14.94it/s]
#  61%|██████    | 1014/1676 [01:09<00:44, 15.01it/s]
#  61%|██████    | 1016/1676 [01:09<00:43, 15.26it/s]
#  61%|██████    | 1018/1676 [01:09<00:42, 15.37it/s]
#  61%|██████    | 1020/1676 [01:09<00:44, 14.58it/s]
#  61%|██████    | 1022/1676 [01:09<00:43, 14.87it/s]
#  61%|██████    | 1024/1676 [01:09<00:43, 15.12it/s]
#  61%|██████    | 1026/1676 [01:10<00:46, 14.01it/s]
#  61%|██████▏   | 1028/1676 [01:10<00:48, 13.35it/s]
#  61%|██████▏   | 1030/1676 [01:10<00:50, 12.91it/s]
#  62%|██████▏   | 1032/1676 [01:10<00:49, 13.09it/s]
#  62%|██████▏   | 1034/1676 [01:10<00:46, 13.76it/s]
#  62%|██████▏   | 1036/1676 [01:10<00:45, 13.96it/s]
#  62%|██████▏   | 1038/1676 [01:10<00:44, 14.44it/s]
#  62%|██████▏   | 1040/1676 [01:11<00:42, 14.79it/s]
#  62%|██████▏   | 1042/1676 [01:11<00:44, 14.36it/s]
#  62%|██████▏   | 1044/1676 [01:11<00:46, 13.54it/s]
#  62%|██████▏   | 1046/1676 [01:11<00:47, 13.38it/s]
#  63%|██████▎   | 1048/1676 [01:11<00:45, 13.71it/s]
#  63%|██████▎   | 1050/1676 [01:11<00:45, 13.61it/s]
#  63%|██████▎   | 1052/1676 [01:11<00:44, 14.09it/s]
#  63%|██████▎   | 1054/1676 [01:12<00:44, 13.88it/s]
#  63%|██████▎   | 1056/1676 [01:12<00:43, 14.37it/s]
#  63%|██████▎   | 1058/1676 [01:12<00:41, 14.79it/s]
#  63%|██████▎   | 1060/1676 [01:12<00:40, 15.05it/s]
#  63%|██████▎   | 1062/1676 [01:12<00:40, 15.29it/s]
#  63%|██████▎   | 1064/1676 [01:12<00:40, 15.15it/s]
#  64%|██████▎   | 1066/1676 [01:12<00:40, 15.02it/s]
#  64%|██████▎   | 1068/1676 [01:12<00:39, 15.22it/s]
#  64%|██████▍   | 1070/1676 [01:13<00:39, 15.37it/s]
#  64%|██████▍   | 1072/1676 [01:13<00:39, 15.48it/s]
#  64%|██████▍   | 1074/1676 [01:13<00:38, 15.52it/s]
#  64%|██████▍   | 1076/1676 [01:13<00:38, 15.59it/s]
#  64%|██████▍   | 1078/1676 [01:13<00:38, 15.62it/s]
#  64%|██████▍   | 1080/1676 [01:13<00:38, 15.57it/s]
#  65%|██████▍   | 1082/1676 [01:13<00:38, 15.35it/s]
#  65%|██████▍   | 1084/1676 [01:14<00:39, 15.06it/s]
#  65%|██████▍   | 1086/1676 [01:14<00:42, 13.99it/s]
#  65%|██████▍   | 1088/1676 [01:14<00:43, 13.49it/s]
#  65%|██████▌   | 1090/1676 [01:14<00:42, 13.88it/s]
#  65%|██████▌   | 1092/1676 [01:14<00:41, 14.20it/s]
#  65%|██████▌   | 1094/1676 [01:14<00:40, 14.42it/s]
#  65%|██████▌   | 1096/1676 [01:14<00:39, 14.71it/s]
#  66%|██████▌   | 1098/1676 [01:15<00:40, 14.41it/s]
#  66%|██████▌   | 1100/1676 [01:15<00:38, 14.83it/s]
#  66%|██████▌   | 1102/1676 [01:15<00:38, 14.97it/s]
#  66%|██████▌   | 1104/1676 [01:15<00:37, 15.16it/s]
#  66%|██████▌   | 1106/1676 [01:15<00:37, 15.39it/s]
#  66%|██████▌   | 1108/1676 [01:15<00:36, 15.51it/s]
#  66%|██████▌   | 1110/1676 [01:15<00:36, 15.56it/s]
#  66%|██████▋   | 1112/1676 [01:15<00:36, 15.58it/s]
#  66%|██████▋   | 1114/1676 [01:16<00:36, 15.56it/s]
#  67%|██████▋   | 1116/1676 [01:16<00:38, 14.41it/s]
#  67%|██████▋   | 1118/1676 [01:16<00:40, 13.63it/s]
#  67%|██████▋   | 1120/1676 [01:16<00:40, 13.68it/s]
#  67%|██████▋   | 1122/1676 [01:16<00:38, 14.25it/s]
#  67%|██████▋   | 1124/1676 [01:16<00:37, 14.74it/s]
#  67%|██████▋   | 1126/1676 [01:16<00:36, 15.02it/s]
#  67%|██████▋   | 1128/1676 [01:17<00:36, 15.16it/s]
#  67%|██████▋   | 1130/1676 [01:17<00:35, 15.21it/s]
#  68%|██████▊   | 1132/1676 [01:17<00:37, 14.40it/s]
#  68%|██████▊   | 1134/1676 [01:17<00:36, 14.76it/s]
#  68%|██████▊   | 1136/1676 [01:17<00:36, 14.99it/s]
#  68%|██████▊   | 1138/1676 [01:17<00:36, 14.63it/s]
#  68%|██████▊   | 1140/1676 [01:17<00:39, 13.71it/s]
#  68%|██████▊   | 1142/1676 [01:18<00:39, 13.50it/s]
#  68%|██████▊   | 1144/1676 [01:18<00:38, 13.75it/s]
#  68%|██████▊   | 1146/1676 [01:18<00:37, 14.07it/s]
#  68%|██████▊   | 1148/1676 [01:18<00:38, 13.88it/s]
#  69%|██████▊   | 1150/1676 [01:18<00:37, 13.98it/s]
#  69%|██████▊   | 1152/1676 [01:18<00:36, 14.52it/s]
#  69%|██████▉   | 1154/1676 [01:18<00:35, 14.83it/s]
#  69%|██████▉   | 1156/1676 [01:18<00:34, 15.05it/s]
#  69%|██████▉   | 1158/1676 [01:19<00:33, 15.27it/s]
#  69%|██████▉   | 1160/1676 [01:19<00:35, 14.64it/s]
#  69%|██████▉   | 1162/1676 [01:19<00:34, 14.92it/s]
#  69%|██████▉   | 1164/1676 [01:19<00:33, 15.08it/s]
#  70%|██████▉   | 1166/1676 [01:19<00:33, 15.27it/s]
#  70%|██████▉   | 1168/1676 [01:19<00:32, 15.40it/s]
#  70%|██████▉   | 1170/1676 [01:19<00:32, 15.50it/s]
#  70%|██████▉   | 1172/1676 [01:20<00:32, 15.55it/s]
#  70%|███████   | 1174/1676 [01:20<00:33, 15.18it/s]
#  70%|███████   | 1176/1676 [01:20<00:34, 14.31it/s]
#  70%|███████   | 1178/1676 [01:20<00:33, 14.66it/s]
#  70%|███████   | 1180/1676 [01:20<00:33, 14.92it/s]
#  71%|███████   | 1182/1676 [01:20<00:32, 15.10it/s]
#  71%|███████   | 1184/1676 [01:20<00:32, 15.26it/s]
#  71%|███████   | 1186/1676 [01:20<00:31, 15.33it/s]
#  71%|███████   | 1188/1676 [01:21<00:31, 15.39it/s]
#  71%|███████   | 1190/1676 [01:21<00:31, 15.42it/s]
#  71%|███████   | 1192/1676 [01:21<00:31, 15.44it/s]
#  71%|███████   | 1194/1676 [01:21<00:31, 15.44it/s]
#  71%|███████▏  | 1196/1676 [01:21<00:31, 15.40it/s]
#  71%|███████▏  | 1198/1676 [01:21<00:30, 15.47it/s]
#  72%|███████▏  | 1200/1676 [01:21<00:30, 15.42it/s]
#  72%|███████▏  | 1202/1676 [01:21<00:30, 15.45it/s]
#  72%|███████▏  | 1204/1676 [01:22<00:30, 15.56it/s]
#  72%|███████▏  | 1206/1676 [01:22<00:30, 15.44it/s]
#  72%|███████▏  | 1208/1676 [01:22<00:31, 15.04it/s]
#  72%|███████▏  | 1210/1676 [01:22<00:31, 14.90it/s]
#  72%|███████▏  | 1212/1676 [01:22<00:30, 15.03it/s]
#  72%|███████▏  | 1214/1676 [01:22<00:30, 15.24it/s]
#  73%|███████▎  | 1216/1676 [01:22<00:30, 15.33it/s]
#  73%|███████▎  | 1218/1676 [01:23<00:29, 15.47it/s]
#  73%|███████▎  | 1220/1676 [01:23<00:29, 15.54it/s]
#  73%|███████▎  | 1222/1676 [01:23<00:29, 15.59it/s]
#  73%|███████▎  | 1224/1676 [01:23<00:29, 15.26it/s]
#  73%|███████▎  | 1226/1676 [01:23<00:30, 14.87it/s]
#  73%|███████▎  | 1228/1676 [01:23<00:31, 14.39it/s]
#  73%|███████▎  | 1230/1676 [01:23<00:30, 14.78it/s]
#  74%|███████▎  | 1232/1676 [01:23<00:29, 14.95it/s]
#  74%|███████▎  | 1234/1676 [01:24<00:30, 14.73it/s]
#  74%|███████▎  | 1236/1676 [01:24<00:29, 14.73it/s]
#  74%|███████▍  | 1238/1676 [01:24<00:29, 14.85it/s]
#  74%|███████▍  | 1240/1676 [01:24<00:29, 14.96it/s]
#  74%|███████▍  | 1242/1676 [01:24<00:28, 15.14it/s]
#  74%|███████▍  | 1244/1676 [01:24<00:29, 14.72it/s]
#  74%|███████▍  | 1246/1676 [01:24<00:28, 14.97it/s]
#  74%|███████▍  | 1248/1676 [01:25<00:30, 14.00it/s]
#  75%|███████▍  | 1250/1676 [01:25<00:32, 13.26it/s]
#  75%|███████▍  | 1252/1676 [01:25<00:32, 12.87it/s]
#  75%|███████▍  | 1254/1676 [01:25<00:31, 13.48it/s]
#  75%|███████▍  | 1256/1676 [01:25<00:30, 13.79it/s]
#  75%|███████▌  | 1258/1676 [01:25<00:29, 13.93it/s]
#  75%|███████▌  | 1260/1676 [01:25<00:31, 13.26it/s]
#  75%|███████▌  | 1262/1676 [01:26<00:29, 13.90it/s]
#  75%|███████▌  | 1264/1676 [01:26<00:28, 14.45it/s]
#  76%|███████▌  | 1266/1676 [01:26<00:27, 14.81it/s]
#  76%|███████▌  | 1268/1676 [01:26<00:27, 14.68it/s]
#  76%|███████▌  | 1270/1676 [01:26<00:28, 14.34it/s]
#  76%|███████▌  | 1272/1676 [01:26<00:27, 14.70it/s]
#  76%|███████▌  | 1274/1676 [01:26<00:28, 14.18it/s]
#  76%|███████▌  | 1276/1676 [01:27<00:27, 14.51it/s]
#  76%|███████▋  | 1278/1676 [01:27<00:28, 13.79it/s]
#  76%|███████▋  | 1280/1676 [01:27<00:29, 13.45it/s]
#  76%|███████▋  | 1282/1676 [01:27<00:28, 13.90it/s]
#  77%|███████▋  | 1284/1676 [01:27<00:27, 14.21it/s]
#  77%|███████▋  | 1286/1676 [01:27<00:27, 14.06it/s]
#  77%|███████▋  | 1288/1676 [01:27<00:27, 14.31it/s]
#  77%|███████▋  | 1290/1676 [01:28<00:26, 14.70it/s]
#  77%|███████▋  | 1292/1676 [01:28<00:27, 14.03it/s]
#  77%|███████▋  | 1294/1676 [01:28<00:28, 13.33it/s]
#  77%|███████▋  | 1296/1676 [01:28<00:27, 13.80it/s]
#  77%|███████▋  | 1298/1676 [01:28<00:26, 14.32it/s]
#  78%|███████▊  | 1300/1676 [01:28<00:26, 14.16it/s]
#  78%|███████▊  | 1302/1676 [01:28<00:27, 13.42it/s]
#  78%|███████▊  | 1304/1676 [01:29<00:26, 14.04it/s]
#  78%|███████▊  | 1306/1676 [01:29<00:26, 14.17it/s]
#  78%|███████▊  | 1308/1676 [01:29<00:27, 13.39it/s]
#  78%|███████▊  | 1310/1676 [01:29<00:26, 13.62it/s]
#  78%|███████▊  | 1312/1676 [01:29<00:25, 14.22it/s]
#  78%|███████▊  | 1314/1676 [01:29<00:24, 14.66it/s]
#  79%|███████▊  | 1316/1676 [01:29<00:24, 14.50it/s]
#  79%|███████▊  | 1318/1676 [01:30<00:25, 14.07it/s]
#  79%|███████▉  | 1320/1676 [01:30<00:24, 14.55it/s]
#  79%|███████▉  | 1322/1676 [01:30<00:23, 14.81it/s]
#  79%|███████▉  | 1324/1676 [01:30<00:23, 15.07it/s]
#  79%|███████▉  | 1326/1676 [01:30<00:23, 15.21it/s]
#  79%|███████▉  | 1328/1676 [01:30<00:23, 14.67it/s]
#  79%|███████▉  | 1330/1676 [01:30<00:23, 14.92it/s]
#  79%|███████▉  | 1332/1676 [01:31<00:22, 15.13it/s]
#  80%|███████▉  | 1334/1676 [01:31<00:22, 14.89it/s]
#  80%|███████▉  | 1336/1676 [01:31<00:24, 13.87it/s]
#  80%|███████▉  | 1338/1676 [01:31<00:23, 14.35it/s]
#  80%|███████▉  | 1340/1676 [01:31<00:22, 14.73it/s]
#  80%|████████  | 1342/1676 [01:31<00:22, 15.03it/s]
#  80%|████████  | 1344/1676 [01:31<00:21, 15.21it/s]
#  80%|████████  | 1346/1676 [01:31<00:22, 14.78it/s]
#  80%|████████  | 1348/1676 [01:32<00:23, 13.98it/s]
#  81%|████████  | 1350/1676 [01:32<00:22, 14.28it/s]
#  81%|████████  | 1352/1676 [01:32<00:22, 14.70it/s]
#  81%|████████  | 1354/1676 [01:32<00:21, 14.79it/s]
#  81%|████████  | 1356/1676 [01:32<00:22, 14.53it/s]
#  81%|████████  | 1358/1676 [01:32<00:21, 14.87it/s]
#  81%|████████  | 1360/1676 [01:32<00:22, 14.24it/s]
#  81%|████████▏ | 1362/1676 [01:33<00:23, 13.54it/s]
#  81%|████████▏ | 1364/1676 [01:33<00:23, 13.30it/s]
#  82%|████████▏ | 1366/1676 [01:33<00:22, 13.89it/s]
#  82%|████████▏ | 1368/1676 [01:33<00:21, 14.27it/s]
#  82%|████████▏ | 1370/1676 [01:33<00:20, 14.62it/s]
#  82%|████████▏ | 1372/1676 [01:33<00:22, 13.67it/s]
#  82%|████████▏ | 1374/1676 [01:33<00:22, 13.66it/s]
#  82%|████████▏ | 1376/1676 [01:34<00:22, 13.52it/s]
#  82%|████████▏ | 1378/1676 [01:34<00:22, 12.99it/s]
#  82%|████████▏ | 1380/1676 [01:34<00:21, 13.63it/s]
#  82%|████████▏ | 1382/1676 [01:34<00:20, 14.06it/s]
#  83%|████████▎ | 1384/1676 [01:34<00:20, 14.41it/s]
#  83%|████████▎ | 1386/1676 [01:34<00:20, 14.19it/s]
#  83%|████████▎ | 1388/1676 [01:34<00:20, 13.73it/s]
#  83%|████████▎ | 1390/1676 [01:35<00:20, 13.91it/s]
#  83%|████████▎ | 1392/1676 [01:35<00:21, 13.22it/s]
#  83%|████████▎ | 1394/1676 [01:35<00:20, 13.44it/s]
#  83%|████████▎ | 1396/1676 [01:35<00:20, 13.95it/s]
#  83%|████████▎ | 1398/1676 [01:35<00:19, 14.29it/s]
#  84%|████████▎ | 1400/1676 [01:35<00:18, 14.55it/s]
#  84%|████████▎ | 1402/1676 [01:35<00:18, 14.90it/s]
#  84%|████████▍ | 1404/1676 [01:36<00:18, 15.06it/s]
#  84%|████████▍ | 1406/1676 [01:36<00:18, 14.93it/s]
#  84%|████████▍ | 1408/1676 [01:36<00:18, 14.30it/s]
#  84%|████████▍ | 1410/1676 [01:36<00:18, 14.50it/s]
#  84%|████████▍ | 1412/1676 [01:36<00:18, 14.39it/s]
#  84%|████████▍ | 1414/1676 [01:36<00:17, 14.79it/s]
#  84%|████████▍ | 1416/1676 [01:36<00:17, 15.05it/s]
#  85%|████████▍ | 1418/1676 [01:37<00:16, 15.21it/s]
#  85%|████████▍ | 1420/1676 [01:37<00:17, 14.81it/s]
#  85%|████████▍ | 1422/1676 [01:37<00:17, 14.84it/s]
#  85%|████████▍ | 1424/1676 [01:37<00:17, 14.20it/s]
#  85%|████████▌ | 1426/1676 [01:37<00:17, 14.57it/s]
#  85%|████████▌ | 1428/1676 [01:37<00:16, 14.84it/s]
#  85%|████████▌ | 1430/1676 [01:37<00:17, 14.34it/s]
#  85%|████████▌ | 1432/1676 [01:38<00:18, 13.46it/s]
#  86%|████████▌ | 1434/1676 [01:38<00:17, 14.03it/s]
#  86%|████████▌ | 1436/1676 [01:38<00:16, 14.40it/s]
#  86%|████████▌ | 1438/1676 [01:38<00:16, 14.57it/s]
#  86%|████████▌ | 1440/1676 [01:38<00:15, 14.84it/s]
#  86%|████████▌ | 1442/1676 [01:38<00:15, 15.08it/s]
#  86%|████████▌ | 1444/1676 [01:38<00:15, 14.65it/s]
#  86%|████████▋ | 1446/1676 [01:39<00:16, 13.75it/s]
#  86%|████████▋ | 1448/1676 [01:39<00:15, 14.30it/s]
#  87%|████████▋ | 1450/1676 [01:39<00:15, 14.51it/s]
#  87%|████████▋ | 1452/1676 [01:39<00:15, 14.30it/s]
#  87%|████████▋ | 1454/1676 [01:39<00:15, 14.36it/s]
#  87%|████████▋ | 1456/1676 [01:39<00:14, 14.76it/s]
#  87%|████████▋ | 1458/1676 [01:39<00:14, 15.10it/s]
#  87%|████████▋ | 1460/1676 [01:39<00:15, 14.27it/s]
#  87%|████████▋ | 1462/1676 [01:40<00:15, 13.46it/s]
#  87%|████████▋ | 1464/1676 [01:40<00:16, 13.11it/s]
#  87%|████████▋ | 1466/1676 [01:40<00:15, 13.73it/s]
#  88%|████████▊ | 1468/1676 [01:40<00:14, 14.23it/s]
#  88%|████████▊ | 1470/1676 [01:40<00:14, 14.19it/s]
#  88%|████████▊ | 1472/1676 [01:40<00:15, 13.44it/s]
#  88%|████████▊ | 1474/1676 [01:41<00:15, 12.99it/s]
#  88%|████████▊ | 1476/1676 [01:41<00:15, 12.67it/s]
#  88%|████████▊ | 1478/1676 [01:41<00:15, 12.41it/s]
#  88%|████████▊ | 1480/1676 [01:41<00:15, 12.31it/s]
#  88%|████████▊ | 1482/1676 [01:41<00:15, 12.20it/s]
#  89%|████████▊ | 1484/1676 [01:41<00:14, 13.07it/s]
#  89%|████████▊ | 1486/1676 [01:41<00:13, 13.76it/s]
#  89%|████████▉ | 1488/1676 [01:42<00:14, 13.17it/s]
#  89%|████████▉ | 1490/1676 [01:42<00:13, 13.84it/s]
#  89%|████████▉ | 1492/1676 [01:42<00:12, 14.34it/s]
#  89%|████████▉ | 1494/1676 [01:42<00:12, 14.68it/s]
#  89%|████████▉ | 1496/1676 [01:42<00:12, 14.86it/s]
#  89%|████████▉ | 1498/1676 [01:42<00:11, 15.02it/s]
#  89%|████████▉ | 1500/1676 [01:42<00:11, 15.21it/s]
#  90%|████████▉ | 1502/1676 [01:43<00:11, 15.39it/s]
#  90%|████████▉ | 1504/1676 [01:43<00:11, 15.52it/s]
#  90%|████████▉ | 1506/1676 [01:43<00:10, 15.64it/s]
#  90%|████████▉ | 1508/1676 [01:43<00:10, 15.60it/s]
#  90%|█████████ | 1510/1676 [01:43<00:10, 15.56it/s]
#  90%|█████████ | 1512/1676 [01:43<00:10, 15.27it/s]
#  90%|█████████ | 1514/1676 [01:43<00:11, 14.52it/s]
#  90%|█████████ | 1516/1676 [01:43<00:10, 14.62it/s]
#  91%|█████████ | 1518/1676 [01:44<00:10, 14.95it/s]
#  91%|█████████ | 1520/1676 [01:44<00:10, 15.18it/s]
#  91%|█████████ | 1522/1676 [01:44<00:10, 15.14it/s]
#  91%|█████████ | 1524/1676 [01:44<00:10, 14.66it/s]
#  91%|█████████ | 1526/1676 [01:44<00:10, 14.63it/s]
#  91%|█████████ | 1528/1676 [01:44<00:10, 14.75it/s]
#  91%|█████████▏| 1530/1676 [01:44<00:10, 13.90it/s]
#  91%|█████████▏| 1532/1676 [01:45<00:10, 13.29it/s]
#  92%|█████████▏| 1534/1676 [01:45<00:10, 13.34it/s]
#  92%|█████████▏| 1536/1676 [01:45<00:10, 12.86it/s]
#  92%|█████████▏| 1538/1676 [01:45<00:10, 13.40it/s]
#  92%|█████████▏| 1540/1676 [01:45<00:09, 13.96it/s]
#  92%|█████████▏| 1542/1676 [01:45<00:09, 13.48it/s]
#  92%|█████████▏| 1544/1676 [01:45<00:10, 13.12it/s]
#  92%|█████████▏| 1546/1676 [01:46<00:09, 13.83it/s]
#  92%|█████████▏| 1548/1676 [01:46<00:08, 14.26it/s]
#  92%|█████████▏| 1550/1676 [01:46<00:08, 14.65it/s]
#  93%|█████████▎| 1552/1676 [01:46<00:08, 14.97it/s]
#  93%|█████████▎| 1554/1676 [01:46<00:07, 15.25it/s]
#  93%|█████████▎| 1556/1676 [01:46<00:07, 15.31it/s]
#  93%|█████████▎| 1558/1676 [01:46<00:08, 14.54it/s]
#  93%|█████████▎| 1560/1676 [01:47<00:07, 14.80it/s]
#  93%|█████████▎| 1562/1676 [01:47<00:07, 15.04it/s]
#  93%|█████████▎| 1564/1676 [01:47<00:07, 14.69it/s]
#  93%|█████████▎| 1566/1676 [01:47<00:07, 13.83it/s]
#  94%|█████████▎| 1568/1676 [01:47<00:07, 14.31it/s]
#  94%|█████████▎| 1570/1676 [01:47<00:07, 14.42it/s]
#  94%|█████████▍| 1572/1676 [01:47<00:07, 14.67it/s]
#  94%|█████████▍| 1574/1676 [01:47<00:06, 14.90it/s]
#  94%|█████████▍| 1576/1676 [01:48<00:06, 14.85it/s]
#  94%|█████████▍| 1578/1676 [01:48<00:06, 14.23it/s]
#  94%|█████████▍| 1580/1676 [01:48<00:07, 13.67it/s]
#  94%|█████████▍| 1582/1676 [01:48<00:06, 14.23it/s]
#  95%|█████████▍| 1584/1676 [01:48<00:06, 14.44it/s]
#  95%|█████████▍| 1586/1676 [01:48<00:06, 14.74it/s]
#  95%|█████████▍| 1588/1676 [01:48<00:05, 14.69it/s]
#  95%|█████████▍| 1590/1676 [01:49<00:06, 14.12it/s]
#  95%|█████████▍| 1592/1676 [01:49<00:05, 14.33it/s]
#  95%|█████████▌| 1594/1676 [01:49<00:05, 14.71it/s]
#  95%|█████████▌| 1596/1676 [01:49<00:05, 14.71it/s]
#  95%|█████████▌| 1598/1676 [01:49<00:05, 14.98it/s]
#  95%|█████████▌| 1600/1676 [01:49<00:05, 15.17it/s]
#  96%|█████████▌| 1602/1676 [01:49<00:04, 15.30it/s]
#  96%|█████████▌| 1604/1676 [01:50<00:04, 15.06it/s]
#  96%|█████████▌| 1606/1676 [01:50<00:04, 15.20it/s]
#  96%|█████████▌| 1608/1676 [01:50<00:04, 15.33it/s]
#  96%|█████████▌| 1610/1676 [01:50<00:04, 15.46it/s]
#  96%|█████████▌| 1612/1676 [01:50<00:04, 14.49it/s]
#  96%|█████████▋| 1614/1676 [01:50<00:04, 14.85it/s]
#  96%|█████████▋| 1616/1676 [01:50<00:04, 13.72it/s]
#  97%|█████████▋| 1618/1676 [01:51<00:04, 14.17it/s]
#  97%|█████████▋| 1620/1676 [01:51<00:04, 13.75it/s]
#  97%|█████████▋| 1622/1676 [01:51<00:03, 14.20it/s]
#  97%|█████████▋| 1624/1676 [01:51<00:03, 14.59it/s]
#  97%|█████████▋| 1626/1676 [01:51<00:03, 14.84it/s]
#  97%|█████████▋| 1628/1676 [01:51<00:03, 15.09it/s]
#  97%|█████████▋| 1630/1676 [01:51<00:03, 15.27it/s]
#  97%|█████████▋| 1632/1676 [01:51<00:02, 15.43it/s]
#  97%|█████████▋| 1634/1676 [01:52<00:02, 14.73it/s]
#  98%|█████████▊| 1636/1676 [01:52<00:02, 14.94it/s]
#  98%|█████████▊| 1638/1676 [01:52<00:02, 15.15it/s]
#  98%|█████████▊| 1640/1676 [01:52<00:02, 15.28it/s]
#  98%|█████████▊| 1642/1676 [01:52<00:02, 15.41it/s]
#  98%|█████████▊| 1644/1676 [01:52<00:02, 15.53it/s]
#  98%|█████████▊| 1646/1676 [01:52<00:01, 15.63it/s]
#  98%|█████████▊| 1648/1676 [01:52<00:01, 15.66it/s]
#  98%|█████████▊| 1650/1676 [01:53<00:01, 15.58it/s]
#  99%|█████████▊| 1652/1676 [01:53<00:01, 15.61it/s]
#  99%|█████████▊| 1654/1676 [01:53<00:01, 15.20it/s]
#  99%|█████████▉| 1656/1676 [01:53<00:01, 14.03it/s]
#  99%|█████████▉| 1658/1676 [01:53<00:01, 14.17it/s]
#  99%|█████████▉| 1660/1676 [01:53<00:01, 14.59it/s]
#  99%|█████████▉| 1662/1676 [01:53<00:00, 14.90it/s]
#  99%|█████████▉| 1664/1676 [01:54<00:00, 14.73it/s]
#  99%|█████████▉| 1666/1676 [01:54<00:00, 14.72it/s]
# 100%|█████████▉| 1668/1676 [01:54<00:00, 14.70it/s]
# 100%|█████████▉| 1670/1676 [01:54<00:00, 14.80it/s]
# 100%|█████████▉| 1672/1676 [01:54<00:00, 14.26it/s]
# 100%|█████████▉| 1674/1676 [01:54<00:00, 14.66it/s]
# 100%|██████████| 1676/1676 [01:54<00:00, 14.96it/s]

# %%
from scipy.special import softmax
test_probs = softmax(test_dists, axis=1)
prototypes = np.array([x.mean() for x in proto_net.prototypes])

# %%
(np.argsort(test_dists, axis=1)[:, :5] == np.argsort(test_probs, axis=1)[:, :5]).mean()
# Out:
# 0.3426014319809069

# %%
top5labels = np.argsort(-test_dists, axis=1)[:, :5] #- is to sort in descending order

top5preds = [test_dists[i][top5labels[i]] for i in range(test_dists.shape[0])]
top5probs = [test_probs[i][top5labels[i]] for i in range(test_dists.shape[0])]

top5probs = np.array(top5probs)
top5preds = np.array(top5preds)

# %%
query_df.columns
# Out:
# Index(['image_path', 'label', 'type', 'label_id', 'split'], dtype='object')

# %%
query_df.columns = ['fpath', 'category', 'type', 'label_id', 'split']

query_df['actual'] = query_df['category']

for i in range(5):
    query_df[f'top_prob'+str(i+1)] = top5probs[:, i]

for i in range(5):
    query_df[f'top_cat'+str(i+1)] = le.inverse_transform(top5labels[:, i])

query_df['pred_cat'] = query_df['top_cat1']

query_df['exp'] = exp

query_df.head()
# Out:
#                                                fpath category   type  \
# 0  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query
# 1  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query
# 2  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query
# 3  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query
# 4  /home/raghava_balusu_walmartlabs_com/Work/ones...  5558787  query
#
#    label_id  split   actual  top_prob1  top_prob2     top_prob3     top_prob4  \
# 0      1410  train  5558787   0.999820   0.000179  1.013340e-06  4.313113e-09
# 1      1410  train  5558787   0.999940   0.000060  7.537661e-18  8.849240e-26
# 2      1410  train  5558787   0.999134   0.000860  4.685828e-06  1.171472e-06
# 3      1410  train  5558787   0.998999   0.001001  7.904924e-09  1.468008e-13
# 4      1410  train  5558787   0.977265   0.022735  1.742623e-07  1.468121e-11
#
#       top_prob5                   top_cat1                     top_cat2  \
# 0  4.154964e-09                    5558787  HouseProducts_Batteries_784
# 1  1.594866e-26                   23296492                     22965966
# 2  1.216695e-07     HealthCare_Face_218818       Food_Dairy_Yoghurt_172
# 3  1.940469e-15  CleaningProducts_Home_164       HealthCare_Face_102206
# 4  8.049399e-12  CleaningProducts_Home_140                      4858662
#
#                        top_cat3                      top_cat4  \
# 0                Food_Coffee_47  CleaningProducts_Home_102111
# 1                       4810552                       5558787
# 2  HouseProducts_Bathroom_98027                Food_Coffee_47
# 3  HouseProducts_Bathroom_98027     CleaningProducts_Home_158
# 4                      23296492      CleaningProducts_Home_24
#
#                        top_cat5                   pred_cat  \
# 0                      23296492                    5558787
# 1                       4810554                   23296492
# 2  HouseProducts_Bathroom_98028     HealthCare_Face_218818
# 3  HouseProducts_Bathroom_98028  CleaningProducts_Home_164
# 4     HouseProducts_Bathroom_39  CleaningProducts_Home_140
#
#                      exp
# 0  BC_q2k100_rq5_ref1.5k
# 1  BC_q2k100_rq5_ref1.5k
# 2  BC_q2k100_rq5_ref1.5k
# 3  BC_q2k100_rq5_ref1.5k
# 4  BC_q2k100_rq5_ref1.5k

# %%
query_df['fpath'] = query_df.fpath.map(lambda x : '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/' + Path(x).name)

query_df['Flag'] = query_df.apply(lambda x: x['actual'] == x['pred_cat'], axis=1)

query_df['Flag_top5'] = query_df.apply(lambda x: x['actual'] in x[['top_cat1', 'top_cat2', 'top_cat3', 'top_cat4', 'top_cat5']].values, axis=1)

print(query_df.Flag.mean(), query_df.Flag_top5.mean())
# Out:
# 0.5698090692124105 0.8210023866348448

# %%
temp = query_df.groupby(['exp', 'category', 'split'])['Flag'].mean().reset_index()
temp.columns = ['exp', 'category','split', 'accuracy_Top1']
query_df = query_df.merge(temp, how='left', on=['exp', 'category', 'split'])

temp = query_df.groupby(['exp', 'category', 'split'])['Flag_top5'].mean().reset_index()
temp.columns = ['exp', 'category', 'split', 'accuracy']
query_df = query_df.merge(temp, how='left', on=['exp', 'category', 'split'])

# %%
# query_df[query_df.split=='train'].fpath.values
# Out:
# array(['/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_5.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_6.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_7.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_8.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073431_940315_9.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073455_951574_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073429_447475_5.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073427_952991_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073427_952991_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073427_952991_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073427_952991_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_5.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_6.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_7.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073448_203673_8.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_698398_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073456_690704_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_21.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_22.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_23.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_24.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073449_947611_25.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073434_696071_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_16.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_17.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073447_698067_18.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073433_945727_9.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073433_945727_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073452_435038_24.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_7.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_8.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073436_950579_9.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073438_695423_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073438_695423_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073438_695423_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073438_695423_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073438_695423_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073437_445342_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073437_445342_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_8.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_9.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073441_444671_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073446_482686_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074246_318892_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073727_696052_16.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_12.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_15.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073722_452872_16.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_5.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_6.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074312_823107_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_18.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_19.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_20.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_21.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073717_450597_22.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074318_071665_19.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073731_964404_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073731_964404_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073731_964404_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073731_964404_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073731_964404_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073713_194889_7.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073713_194889_8.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073713_194889_9.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073713_194889_10.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073713_194889_11.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074315_830577_16.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074315_830577_17.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074315_830577_18.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073726_695217_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073726_695217_1.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073726_695217_2.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073726_695217_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073726_695217_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074321_821416_3.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031020_074321_821416_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031220_081607_651496_4.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_945481_13.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_011320_073439_945481_14.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031820_084515_175363_0.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_030920_080448_737947_16.jpg',
#        '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/SamsClub6235_031220_081618_157971_16.jpg'],
#       dtype=object)

# %%
query_df.tail()
# Out:
#                                                   fpath category   type  \
# 1671  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  4810554  query
# 1672  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  4810554  query
# 1673  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  4810554  query
# 1674  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  4810554  query
# 1675  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  4810554  query
#
#       label_id  split   actual  top_prob1     top_prob2     top_prob3  \
# 1671       469  valid  4810554   0.930952  6.904832e-02  7.824354e-09
# 1672       469  valid  4810554   1.000000  6.150504e-10  1.124491e-13
# 1673       469  valid  4810554   1.000000  1.879601e-12  1.111173e-23
# 1674       469  valid  4810554   1.000000  5.832542e-14  5.808764e-16
# 1675       469  valid  4810554   0.999994  6.220384e-06  1.370812e-07
#
#          top_prob4    ...     top_cat2 top_cat3  top_cat4  top_cat5 pred_cat  \
# 1671  2.289855e-14    ...      4810550  5186005  23296492   4810552  4810554
# 1672  3.613324e-17    ...      4810552  4810550  54082010  23296492  4810554
# 1673  1.374991e-29    ...      4810552  4810550  29566609   5186005  4810554
# 1674  3.764980e-20    ...      4810552  4810550   5186005  23296492  4810554
# 1675  3.775429e-16    ...      5186005  4810550   4810552  37989538  4810554
#
#                         exp  Flag Flag_top5  accuracy_Top1  accuracy
# 1671  BC_q2k100_rq5_ref1.5k  True      True           0.75  0.964286
# 1672  BC_q2k100_rq5_ref1.5k  True      True           0.75  0.964286
# 1673  BC_q2k100_rq5_ref1.5k  True      True           0.75  0.964286
# 1674  BC_q2k100_rq5_ref1.5k  True      True           0.75  0.964286
# 1675  BC_q2k100_rq5_ref1.5k  True      True           0.75  0.964286
#
# [5 rows x 22 columns]

# %%
# bc_proto_results = pd.DataFrame({'fpath':[str(i).replace('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data', '/Users/r0b03m2/Desktop/Work/braincorp_data') for i in ref],
#               'category' : [i.parent.name for i in ref],
#               'exp': ['dummy' for i in range(len(ref))]})

# bc_proto_results.head()

# %%
exp
# Out:
# 'BC_q2k100_rq5_ref1.5k'

# %%
# result_df.to_csv('results/bc_proto_results.csv', index=False)

# %%
result_df = pd.read_csv('results/bc_proto_results.csv')
# result_df = bc_proto_results

# %%
result_df.to_csv('results/bc_proto_results.csv', index=False)

# %%
result_df['Flag'] = result_df.Flag.map({'nan': np.nan, False: 0, True: 1})
result_df['Flag_top5'] = result_df.Flag_top5.map({'nan': np.nan, False: 0, True: 1})

# %%
result_df.drop(['accuracy', 'accuracy_Top1'], axis=1, inplace=True)

# %%
result_df.tail()
# Out:
#                                                    fpath  category   type  \
# 38381  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554  query
# 38382  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554  query
# 38383  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554  query
# 38384  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554  query
# 38385  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554  query
#
#        label_id     actual  top_prob1     top_prob2     top_prob3  \
# 38381     469.0  4810554.0   0.930952  6.904832e-02  7.824354e-09
# 38382     469.0  4810554.0   1.000000  6.150504e-10  1.124491e-13
# 38383     469.0  4810554.0   1.000000  1.879601e-12  1.111173e-23
# 38384     469.0  4810554.0   1.000000  5.832542e-14  5.808764e-16
# 38385     469.0  4810554.0   0.999994  6.220384e-06  1.370812e-07
#
#           top_prob4     top_prob5    ...      top_cat3    top_cat4  \
# 38381  2.289855e-14  3.132165e-18    ...     5186005.0  23296492.0
# 38382  3.613324e-17  2.811344e-17    ...     4810550.0  54082010.0
# 38383  1.374991e-29  7.996715e-32    ...     4810550.0  29566609.0
# 38384  3.764980e-20  8.711851e-28    ...     4810550.0   5186005.0
# 38385  3.775429e-16  1.560768e-28    ...     4810550.0   4810552.0
#
#          top_cat5   pred_cat                    exp  Flag Flag_top5  split  \
# 38381   4810552.0  4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38382  23296492.0  4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38383   5186005.0  4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38384  23296492.0  4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38385  37989538.0  4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
#
#        accuracy_Top1  accuracy
# 38381       0.734177  0.962025
# 38382       0.734177  0.962025
# 38383       0.734177  0.962025
# 38384       0.734177  0.962025
# 38385       0.734177  0.962025
#
# [5 rows x 22 columns]

# %%
# result_df.astype({'fpath': str, 'category': np.float64, 'type': str, 'label_id': np.float64, 
#                   'actual': np.float64, 'top_prob1':np.float64,
#        'top_prob2':np.float64, 'top_prob3':np.float64, 'top_prob4':np.float64, 'top_prob5':np.float64, 
#         'top_cat1':np.float64, 'top_cat2':np.float64, 'top_cat3':np.float64, 'top_cat4':np.float64, 'top_cat5':np.float64,
#                   'pred_cat':np.float64, 'exp':str, 'Flag':np.float64, 'Flag_top5':np.float64, 'split':str,
#                   'accuracy_Top1':np.float64, 'accuracy':np.float64})
# Out:
#                                                    fpath    category   type  \
# 0      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  50038959.0    nan
# 1      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53425502.0    nan
# 2      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  31184578.0    nan
# 3      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53132214.0    nan
# 4      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53050477.0    nan
# 5      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  51212183.0    nan
# 6      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  30923213.0    nan
# 7      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  31586269.0    nan
# 8      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  31536538.0    nan
# 9      /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53482682.0    nan
# 10     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...   5529370.0    nan
# 11     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53881410.0    nan
# 12     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53798219.0    nan
# 13     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...   2970126.0    nan
# 14     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  54525924.0    nan
# 15     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  54480487.0    nan
# 16     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  31554804.0    nan
# 17     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53721736.0    nan
# 18     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  54518598.0    nan
# 19     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  54261746.0    nan
# 20     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  53643897.0    nan
# 21     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  31586265.0    nan
# 22     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  24301014.0    nan
# 23     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  52751718.0    nan
# 24     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...   3908307.0    nan
# 25     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  29830944.0    nan
# 26     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  46686007.0    nan
# 27     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...   5659403.0    nan
# 28     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  21202250.0    nan
# 29     /Users/r0b03m2/Desktop/Work/braincorp_data/ref...  54246963.0    nan
# ...                                                  ...         ...    ...
# 38356  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38357  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38358  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38359  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38360  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38361  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  53197162.0  query
# 38362  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  53197162.0  query
# 38363  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  53197162.0  query
# 38364  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  53197162.0  query
# 38365  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38366  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38367  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54217299.0  query
# 38368  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   5262834.0  query
# 38369  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   5262834.0  query
# 38370  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   5262834.0  query
# 38371  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54747442.0  query
# 38372  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54747442.0  query
# 38373  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  54747442.0  query
# 38374  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38375  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38376  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38377  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38378  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38379  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38380  /Users/r0b03m2/Desktop/Work/braincorp_data/que...  29566609.0  query
# 38381  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554.0  query
# 38382  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554.0  query
# 38383  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554.0  query
# 38384  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554.0  query
# 38385  /Users/r0b03m2/Desktop/Work/braincorp_data/que...   4810554.0  query
#
#        label_id      actual  top_prob1     top_prob2     top_prob3  \
# 0           NaN         NaN        NaN           NaN           NaN
# 1           NaN         NaN        NaN           NaN           NaN
# 2           NaN         NaN        NaN           NaN           NaN
# 3           NaN         NaN        NaN           NaN           NaN
# 4           NaN         NaN        NaN           NaN           NaN
# 5           NaN         NaN        NaN           NaN           NaN
# 6           NaN         NaN        NaN           NaN           NaN
# 7           NaN         NaN        NaN           NaN           NaN
# 8           NaN         NaN        NaN           NaN           NaN
# 9           NaN         NaN        NaN           NaN           NaN
# 10          NaN         NaN        NaN           NaN           NaN
# 11          NaN         NaN        NaN           NaN           NaN
# 12          NaN         NaN        NaN           NaN           NaN
# 13          NaN         NaN        NaN           NaN           NaN
# 14          NaN         NaN        NaN           NaN           NaN
# 15          NaN         NaN        NaN           NaN           NaN
# 16          NaN         NaN        NaN           NaN           NaN
# 17          NaN         NaN        NaN           NaN           NaN
# 18          NaN         NaN        NaN           NaN           NaN
# 19          NaN         NaN        NaN           NaN           NaN
# 20          NaN         NaN        NaN           NaN           NaN
# 21          NaN         NaN        NaN           NaN           NaN
# 22          NaN         NaN        NaN           NaN           NaN
# 23          NaN         NaN        NaN           NaN           NaN
# 24          NaN         NaN        NaN           NaN           NaN
# 25          NaN         NaN        NaN           NaN           NaN
# 26          NaN         NaN        NaN           NaN           NaN
# 27          NaN         NaN        NaN           NaN           NaN
# 28          NaN         NaN        NaN           NaN           NaN
# 29          NaN         NaN        NaN           NaN           NaN
# ...         ...         ...        ...           ...           ...
# 38356    1220.0  54217299.0   1.000000  7.042276e-21  1.271351e-21
# 38357    1220.0  54217299.0   1.000000  1.350755e-21  1.713307e-25
# 38358    1220.0  54217299.0   1.000000  8.355839e-19  1.078163e-26
# 38359    1220.0  54217299.0   1.000000  1.980383e-22  6.016415e-24
# 38360    1220.0  54217299.0   1.000000  1.233093e-18  7.687137e-27
# 38361     773.0  53197162.0   1.000000  9.504853e-25  1.816739e-26
# 38362     773.0  53197162.0   1.000000  7.187543e-18  1.478351e-27
# 38363     773.0  53197162.0   0.999849  1.511977e-04  3.463948e-10
# 38364     773.0  53197162.0   0.996265  3.687228e-03  2.796463e-05
# 38365    1220.0  54217299.0   1.000000  1.105099e-11  2.706949e-13
# 38366    1220.0  54217299.0   1.000000  2.235637e-10  3.022828e-14
# 38367    1220.0  54217299.0   1.000000  8.917836e-10  1.435986e-13
# 38368     650.0   5262834.0   0.987058  1.294233e-02  9.625600e-21
# 38369     650.0   5262834.0   0.996676  3.324094e-03  5.332697e-38
# 38370     650.0   5262834.0   0.999989  1.098504e-05  5.026834e-35
# 38371    1395.0  54747442.0   1.000000  3.783952e-14  5.371856e-15
# 38372    1395.0  54747442.0   0.999531  4.687555e-04  2.669636e-10
# 38373    1395.0  54747442.0   0.727073  2.729269e-01  2.484887e-09
# 38374     181.0  29566609.0   1.000000  2.772742e-22  2.206324e-30
# 38375     181.0  29566609.0   1.000000  2.744291e-15  4.904245e-31
# 38376     181.0  29566609.0   1.000000  8.698936e-16  2.204297e-29
# 38377     181.0  29566609.0   1.000000  4.481341e-08  4.894899e-12
# 38378     181.0  29566609.0   0.999998  1.530049e-06  2.357650e-11
# 38379     181.0  29566609.0   0.894203  1.057973e-01  2.037131e-13
# 38380     181.0  29566609.0   1.000000  2.841303e-18  5.364725e-29
# 38381     469.0   4810554.0   0.930952  6.904832e-02  7.824354e-09
# 38382     469.0   4810554.0   1.000000  6.150504e-10  1.124491e-13
# 38383     469.0   4810554.0   1.000000  1.879601e-12  1.111173e-23
# 38384     469.0   4810554.0   1.000000  5.832542e-14  5.808764e-16
# 38385     469.0   4810554.0   0.999994  6.220384e-06  1.370812e-07
#
#           top_prob4     top_prob5    ...       top_cat3    top_cat4  \
# 0               NaN           NaN    ...            NaN         NaN
# 1               NaN           NaN    ...            NaN         NaN
# 2               NaN           NaN    ...            NaN         NaN
# 3               NaN           NaN    ...            NaN         NaN
# 4               NaN           NaN    ...            NaN         NaN
# 5               NaN           NaN    ...            NaN         NaN
# 6               NaN           NaN    ...            NaN         NaN
# 7               NaN           NaN    ...            NaN         NaN
# 8               NaN           NaN    ...            NaN         NaN
# 9               NaN           NaN    ...            NaN         NaN
# 10              NaN           NaN    ...            NaN         NaN
# 11              NaN           NaN    ...            NaN         NaN
# 12              NaN           NaN    ...            NaN         NaN
# 13              NaN           NaN    ...            NaN         NaN
# 14              NaN           NaN    ...            NaN         NaN
# 15              NaN           NaN    ...            NaN         NaN
# 16              NaN           NaN    ...            NaN         NaN
# 17              NaN           NaN    ...            NaN         NaN
# 18              NaN           NaN    ...            NaN         NaN
# 19              NaN           NaN    ...            NaN         NaN
# 20              NaN           NaN    ...            NaN         NaN
# 21              NaN           NaN    ...            NaN         NaN
# 22              NaN           NaN    ...            NaN         NaN
# 23              NaN           NaN    ...            NaN         NaN
# 24              NaN           NaN    ...            NaN         NaN
# 25              NaN           NaN    ...            NaN         NaN
# 26              NaN           NaN    ...            NaN         NaN
# 27              NaN           NaN    ...            NaN         NaN
# 28              NaN           NaN    ...            NaN         NaN
# 29              NaN           NaN    ...            NaN         NaN
# ...             ...           ...    ...            ...         ...
# 38356  6.723495e-33  8.882470e-40    ...     48220676.0   5262834.0
# 38357  1.357214e-33  7.503481e-44    ...     48220676.0   5262834.0
# 38358  4.100908e-32  2.397682e-41    ...      5262834.0  48220676.0
# 38359  2.392692e-29  2.183736e-29    ...      5262834.0  50767088.0
# 38360  1.449306e-27  1.108830e-41    ...      5262834.0  48220676.0
# 38361  1.704665e-29  1.093284e-32    ...     54565142.0  50553539.0
# 38362  8.596048e-28  1.510876e-33    ...     53621633.0  54565142.0
# 38363  2.504959e-10  7.782504e-11    ...     54565142.0  52837880.0
# 38364  1.826094e-05  9.457977e-07    ...     52867343.0   5730711.0
# 38365  3.838409e-16  2.985414e-21    ...     54217295.0  48220676.0
# 38366  2.384858e-14  7.127916e-22    ...      6986914.0  54217295.0
# 38367  1.169039e-15  1.467323e-18    ...      6986914.0   5262834.0
# 38368  9.773034e-27  6.297714e-27    ...     53537941.0  31613801.0
# 38369  5.105204e-38  3.655068e-40    ...     52436930.0  54747442.0
# 38370  2.929442e-41  4.224766e-43    ...     52436930.0  54656588.0
# 38371  8.672593e-22  3.423775e-24    ...     54747442.0  53504863.0
# 38372  8.141755e-19  8.142599e-25    ...      4385267.0  54656588.0
# 38373  3.908476e-10  5.112689e-19    ...     53983165.0   5262834.0
# 38374  1.268861e-31  4.987702e-32    ...     29566609.0  38957303.0
# 38375  1.066708e-32  3.507698e-34    ...     22965966.0   4810554.0
# 38376  1.915048e-31  1.068336e-31    ...     22965966.0  29566609.0
# 38377  1.585766e-15  2.151153e-22    ...      4810554.0  29566609.0
# 38378  2.892127e-26  1.546052e-27    ...     22965966.0   4810554.0
# 38379  2.282164e-15  1.332309e-17    ...     22965966.0  29566609.0
# 38380  2.881818e-29  1.884098e-33    ...      4810554.0  29566609.0
# 38381  2.289855e-14  3.132165e-18    ...      5186005.0  23296492.0
# 38382  3.613324e-17  2.811344e-17    ...      4810550.0  54082010.0
# 38383  1.374991e-29  7.996715e-32    ...      4810550.0  29566609.0
# 38384  3.764980e-20  8.711851e-28    ...      4810550.0   5186005.0
# 38385  3.775429e-16  1.560768e-28    ...      4810550.0   4810552.0
#
#          top_cat5    pred_cat                    exp  Flag Flag_top5  split  \
# 0             NaN         NaN                  dummy   NaN       NaN  valid
# 1             NaN         NaN                  dummy   NaN       NaN  valid
# 2             NaN         NaN                  dummy   NaN       NaN  valid
# 3             NaN         NaN                  dummy   NaN       NaN  valid
# 4             NaN         NaN                  dummy   NaN       NaN  valid
# 5             NaN         NaN                  dummy   NaN       NaN  valid
# 6             NaN         NaN                  dummy   NaN       NaN  valid
# 7             NaN         NaN                  dummy   NaN       NaN  valid
# 8             NaN         NaN                  dummy   NaN       NaN  valid
# 9             NaN         NaN                  dummy   NaN       NaN  valid
# 10            NaN         NaN                  dummy   NaN       NaN  valid
# 11            NaN         NaN                  dummy   NaN       NaN  valid
# 12            NaN         NaN                  dummy   NaN       NaN  valid
# 13            NaN         NaN                  dummy   NaN       NaN  valid
# 14            NaN         NaN                  dummy   NaN       NaN  valid
# 15            NaN         NaN                  dummy   NaN       NaN  valid
# 16            NaN         NaN                  dummy   NaN       NaN  valid
# 17            NaN         NaN                  dummy   NaN       NaN  valid
# 18            NaN         NaN                  dummy   NaN       NaN  valid
# 19            NaN         NaN                  dummy   NaN       NaN  valid
# 20            NaN         NaN                  dummy   NaN       NaN  valid
# 21            NaN         NaN                  dummy   NaN       NaN  valid
# 22            NaN         NaN                  dummy   NaN       NaN  valid
# 23            NaN         NaN                  dummy   NaN       NaN  valid
# 24            NaN         NaN                  dummy   NaN       NaN  valid
# 25            NaN         NaN                  dummy   NaN       NaN  valid
# 26            NaN         NaN                  dummy   NaN       NaN  valid
# 27            NaN         NaN                  dummy   NaN       NaN  valid
# 28            NaN         NaN                  dummy   NaN       NaN  valid
# 29            NaN         NaN                  dummy   NaN       NaN  valid
# ...           ...         ...                    ...   ...       ...    ...
# 38356  54656588.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38357   6986914.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38358   4385267.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38359   6986914.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38360  54656588.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38361  42430527.0  53197162.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38362  31613801.0  53197162.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38363  31613801.0  53197162.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38364  54747442.0  53197162.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38365   5262834.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38366  48220676.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38367  48220676.0  54217299.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38368  54565142.0   4385267.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38369  53537941.0   5262834.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38370  54565142.0   5262834.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38371  53196492.0   5262834.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38372  53504863.0   5262834.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38373  31613801.0  54747442.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38374   4810554.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38375  29566609.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38376  37989538.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38377   4810550.0   4810552.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38378  29566609.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38379   4810554.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38380  22965966.0  23296492.0  BC_q2k100_rq5_ref1.5k   0.0       1.0  valid
# 38381   4810552.0   4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38382  23296492.0   4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38383   5186005.0   4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38384  23296492.0   4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
# 38385  37989538.0   4810554.0  BC_q2k100_rq5_ref1.5k   1.0       1.0  valid
#
#        accuracy_Top1  accuracy
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
# 5                NaN       NaN
# 6                NaN       NaN
# 7                NaN       NaN
# 8                NaN       NaN
# 9                NaN       NaN
# 10               NaN       NaN
# 11               NaN       NaN
# 12               NaN       NaN
# 13               NaN       NaN
# 14               NaN       NaN
# 15               NaN       NaN
# 16               NaN       NaN
# 17               NaN       NaN
# 18               NaN       NaN
# 19               NaN       NaN
# 20               NaN       NaN
# 21               NaN       NaN
# 22               NaN       NaN
# 23               NaN       NaN
# 24               NaN       NaN
# 25               NaN       NaN
# 26               NaN       NaN
# 27               NaN       NaN
# 28               NaN       NaN
# 29               NaN       NaN
# ...              ...       ...
# 38356       0.903226  0.903226
# 38357       0.903226  0.903226
# 38358       0.903226  0.903226
# 38359       0.903226  0.903226
# 38360       0.903226  0.903226
# 38361       0.789474  0.947368
# 38362       0.789474  0.947368
# 38363       0.789474  0.947368
# 38364       0.789474  0.947368
# 38365       0.903226  0.903226
# 38366       0.903226  0.903226
# 38367       0.903226  0.903226
# 38368       0.571429  1.000000
# 38369       0.571429  1.000000
# 38370       0.571429  1.000000
# 38371       0.023810  0.380952
# 38372       0.023810  0.380952
# 38373       0.023810  0.380952
# 38374       0.141667  0.941667
# 38375       0.141667  0.941667
# 38376       0.141667  0.941667
# 38377       0.141667  0.941667
# 38378       0.141667  0.941667
# 38379       0.141667  0.941667
# 38380       0.141667  0.941667
# 38381       0.734177  0.962025
# 38382       0.734177  0.962025
# 38383       0.734177  0.962025
# 38384       0.734177  0.962025
# 38385       0.734177  0.962025
#
# [38386 rows x 22 columns]

# %%
temp = result_df.groupby(['exp', 'category', 'split'])['Flag'].mean().reset_index()
temp.columns = ['exp', 'category','split', 'accuracy_Top1']
result_df = result_df.merge(temp, how='left', on=['exp', 'category', 'split'])

temp = result_df.groupby(['exp', 'category', 'split'])['Flag_top5'].mean().reset_index()
temp.columns = ['exp', 'category', 'split','accuracy']
result_df = result_df.merge(temp, how='left', on=['exp', 'category', 'split'])

# %%
# result_df.drop(result_df[result_df.exp == 'Grocer_res34_s1_q2_k80_epoch100'].index.values, inplace=True, axis=0)

# %%
fin_df = result_df.append(query_df, ignore_index=True)

# %%
fin_df.tail()
# Out:
#        Flag Flag_top5  accuracy  accuracy_Top1   actual category  \
# 38381  True      True  0.964286           0.75  4810554  4810554
# 38382  True      True  0.964286           0.75  4810554  4810554
# 38383  True      True  0.964286           0.75  4810554  4810554
# 38384  True      True  0.964286           0.75  4810554  4810554
# 38385  True      True  0.964286           0.75  4810554  4810554
#
#                          exp  \
# 38381  BC_q2k100_rq5_ref1.5k
# 38382  BC_q2k100_rq5_ref1.5k
# 38383  BC_q2k100_rq5_ref1.5k
# 38384  BC_q2k100_rq5_ref1.5k
# 38385  BC_q2k100_rq5_ref1.5k
#
#                                                    fpath  label_id pred_cat  \
# 38381  /Users/r0b03m2/Desktop/Work/braincorp_data/que...     469.0  4810554
# 38382  /Users/r0b03m2/Desktop/Work/braincorp_data/que...     469.0  4810554
# 38383  /Users/r0b03m2/Desktop/Work/braincorp_data/que...     469.0  4810554
# 38384  /Users/r0b03m2/Desktop/Work/braincorp_data/que...     469.0  4810554
# 38385  /Users/r0b03m2/Desktop/Work/braincorp_data/que...     469.0  4810554
#
#        ...   top_cat2 top_cat3  top_cat4  top_cat5 top_prob1     top_prob2  \
# 38381  ...    4810550  5186005  23296492   4810552  0.930952  6.904832e-02
# 38382  ...    4810552  4810550  54082010  23296492  1.000000  6.150504e-10
# 38383  ...    4810552  4810550  29566609   5186005  1.000000  1.879601e-12
# 38384  ...    4810552  4810550   5186005  23296492  1.000000  5.832542e-14
# 38385  ...    5186005  4810550   4810552  37989538  0.999994  6.220384e-06
#
#           top_prob3     top_prob4     top_prob5   type
# 38381  7.824354e-09  2.289855e-14  3.132165e-18  query
# 38382  1.124491e-13  3.613324e-17  2.811344e-17  query
# 38383  1.111173e-23  1.374991e-29  7.996715e-32  query
# 38384  5.808764e-16  3.764980e-20  8.711851e-28  query
# 38385  1.370812e-07  3.775429e-16  1.560768e-28  query
#
# [5 rows x 22 columns]

# %%
fin_df = fin_df[['fpath', 'category', 'type', 'label_id', 'actual', 'top_prob1',
       'top_prob2', 'top_prob3', 'top_prob4', 'top_prob5', 'top_cat1',
       'top_cat2', 'top_cat3', 'top_cat4', 'top_cat5', 'pred_cat', 'exp',
       'Flag', 'Flag_top5', 'accuracy', 'accuracy_Top1', 'split']]

# %%
fin_df.groupby(['exp', 'split']).aggregate({'accuracy': np.mean})
# Out:
#                               accuracy
# exp                    split
# BC_q10k25ref1.5k       train  0.707692
#                        valid  0.695041
# BC_q2k100_ref1.5k      train  0.970588
#                        valid  0.807214
# BC_q2k100_rq10_ref1.5k train  0.941538
#                        valid  0.845300
# BC_q2k100_rq5_ref1.5k  train  0.935294
#                        valid  0.896414
# BC_q2k80onlyref1.5k    valid  0.288783
# BC_q5k25_ref1.5k       train  0.800000
#                        valid  0.688579
# BC_q5k50_rq10_ref1.5k  train  0.870769
#                        valid  0.827535
# BC_q5k50ref1.5k        train  0.858824
#                        valid  0.752324
# GP_185refqcls          valid  0.477924
# GP_185refqcls_ref1.5k  valid  0.136635
# GP_nonq7.6k            valid  0.658711
# GP_nonq7.6k_ref1.5k    valid  0.319212
# GP_nonq7.8k            valid  0.585919
# GP_nonq7.8k_ref1.5k    valid  0.269690
# GP_onlyref             valid  0.572792
# GP_onlyref2.5k         valid  0.642601
# GP_onlyref2.5k_ref1.5k valid  0.338305
# GP_onlyref_ref1.5k     valid  0.269690
# GP_onlyrefhard         valid  0.622315
# GP_onlyrefhard_ref1.5k valid  0.316826
# dummy                  valid       NaN
# res_untrained          valid  0.562649
# res_untrained_ref1.5k  valid  0.222554

# %%
# fin_df['exp'] = fin_df.exp.map({'dummy':'dummy', 
#  'GP_185refqcls_ref1.5k': 'GP_185refqcls_ref1.5k', 
#  'GP_185refqcls':'GP_185refqcls', 
#  'res_untrained': 'res_untrained',
#  'GP_nonq7.8k': 'GP_nonq7.8k', 
#  'GP_nonq7.6k': 'GP_nonq7.6k', 
#  'GP_onlyref2.5k': 'GP_onlyref2.5k', 
#  'GP_onlyrefhard': 'GP_onlyrefhard',      
#  'GP_onlyref': 'GP_onlyref', 
#  'res_untrained_ref1.5k': 'res_untrained_ref1.5k', 
#  'GP_nonq7.8k_ref1.5k': 'GP_nonq7.8k_ref1.5k',
#  'GP_nonq7.6k_ref1.5k': 'GP_nonq7.6k_ref1.5k', 
#  'GP_onlyref2.5k_ref1.5k': 'GP_onlyref2.5k_ref1.5k',
#  'GP_onlyrefhard_ref1.5k': 'GP_onlyrefhard_ref1.5k', 
#  'GP_onlyref_ref1.5k': 'GP_onlyref_ref1.5k', 
#  'BC_onlyref1.5k': 'BC_q2k80onlyref1.5k',
#  'BC_q5ref1.5k': 'BC_q5k50ref1.5k', 
#  'BC_q10ref1.5k': 'BC_q10k25ref1.5k', 
#  'BC_q5k25_ref1.5k': 'BC_q5k25_ref1.5k'})

# %%
# fin_df.columns = ['fpath', 'category', 'type', 'label_id', 'actual', 'top_prob1',
#        'top_prob2', 'top_prob3', 'top_prob4', 'top_prob5', 'top_cat1',
#        'top_cat2', 'top_cat3', 'top_cat4', 'top_cat5', 'pred_cat', 'exp',
#        'Flag', 'Flag_top5', 'accuracy_Top1', 'accuracy', 'split']

# %%
fin_df.to_csv('results/bc_proto_results.csv', index=False)

# %%
fin_df[fin_df.split=='valid'].to_csv('results/bc_proto_valid_results.csv', index=False)

# %%
# fin_df['exp'] = fin_df.exp.map(lambda x : x.replace('_only37', '').replace('.pth',''))

# %%
fin_df.exp.unique()
# Out:
# array(['dummy', 'GP_185refqcls_ref1.5k', 'GP_185refqcls', 'res_untrained',
#        'GP_nonq7.8k', 'GP_nonq7.6k', 'GP_onlyref2.5k', 'GP_onlyrefhard',
#        'GP_onlyref', 'res_untrained_ref1.5k', 'GP_nonq7.8k_ref1.5k',
#        'GP_nonq7.6k_ref1.5k', 'GP_onlyref2.5k_ref1.5k',
#        'GP_onlyrefhard_ref1.5k', 'GP_onlyref_ref1.5k',
#        'BC_q2k80onlyref1.5k', 'BC_q5k50ref1.5k', 'BC_q10k25ref1.5k',
#        'BC_q5k25_ref1.5k', 'BC_q5k50_rq10_ref1.5k',
#        'BC_q2k100_rq10_ref1.5k', 'BC_q2k100_ref1.5k'], dtype=object)

# %%
query_df[query_df.split=='train'].to_csv('results/bc_proto_train_results.csv', index=False)

# %% [markdown]
# #### Topn Accuracy
#
# * 1514 ref Images
#     * 34 Ref classes ahve query images as well
#     *1480 with augmentation
#     * test - 34 images  with out 5 query not in trainign

# %%
topn = 25

topnlabels = np.argsort(-test_dists, axis=1)[:, :topn] #- is to sort in descending order

topnpreds = [test_dists[i][topnlabels[i]] for i in range(test_dists.shape[0])]
topnprobs = [test_probs[i][topnlabels[i]] for i in range(test_dists.shape[0])]

topnprobs = np.array(topnprobs)
topnpreds = np.array(topnpreds)

for i in range(topn):
    query_df[f'top_prob'+str(i+1)] = topnprobs[:, i]

for i in range(topn):
    query_df[f'top_cat'+str(i+1)] = le.inverse_transform(topnlabels[:, i])

topn_cols = [f'top_cat{i+1}' for i in range(topn)]
query_df['Flag_topn'] = query_df.apply(lambda x: x['actual'] in x[topn_cols].values, axis=1)

print(query_df.Flag.mean(), query_df.Flag_top5.mean(), query_df.Flag_topn.mean())
# Out:
# 0.5698090692124105 0.8210023866348448 0.9206443914081146

# %%
query_df.to_csv('results/BC_q2k100_rq5_ref1.5k_Top25reco.csv')

# %%
fin_df.exp.unique()
# Out:
# array(['dummy', 'Grocer_res34_s1_q2_k80_e101_ref1.5k',
#        'Grocer_res34_s1_q2_k80_e101', 'res_untrained',
#        'Grocer_res34_s1_q2_k80_nonq7.8k_epoch100',
#        'Grocer_res34_s1_q2_k80_nonq7.6k_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyref2.5k_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyrefhard_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyref_epoch100', 'res_untrained_ref1.5k',
#        'Grocer_res34_s1_q2_k80_nonq7.8k_ref1.5k'], dtype=object)

# %%
fin_df.exp.unique()[5:-2]
# Out:
# array(['Grocer_res34_s1_q2_k80_nonq7.6k_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyref2.5k_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyrefhard_epoch100',
#        'Grocer_res34_s1_q2_k80_onlyref_epoch100'], dtype=object)

# %%
for i in ['Grocer_res34_s1_q2_k80_nonq7.6k_epoch100',
       'Grocer_res34_s1_q2_k80_onlyref2.5k_epoch100',
       'Grocer_res34_s1_q2_k80_onlyrefhard_epoch100',
       'Grocer_res34_s1_q2_k80_onlyref_epoch100']:
    args.param_str = i.replace('_epoch100','')
    # exp = f'{args.param_str}_epoch{args.n_epochs}' + '_ref1.5k'
    exp = i.replace('_epoch100','')+'_ref1.5k'
    print(exp)
    get_model_fn=get_resnet34
    weight_file = f'models/{args.param_str}_e{args.n_epochs+1}.pth'
    output_path='results'


    DATA_PATH = '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/'

    SZ=256
    device='cuda'
    train_csv=DATA_PATH+'/train.csv'
    data_train = DATA_PATH
    data_test  = DATA_PATH
    data_type='normal'
    normalize='imagenet'
    N_TTA=0
    part=0
    n_part=1

    weight_file = Path(weight_file)
    output_path = Path(output_path)
    ensure_folder(output_path)

    ref = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_img').glob('*/*.png'))]
    aisle = [i for i in list(Path('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/ref_38').glob('*/*.png'))]
    # ref = aisle

    proto_df = pd.DataFrame({'image_path' : [str(i) for i in ref], 'label' : [i.parent.name for i in ref]})
    proto_df['type'] = 'reference'

    le = LabelEncoder()
    proto_df['label_id'] = le.fit_transform(proto_df.label)

    proto_df.head()

    query_df = pd.read_csv('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/img_to_labels.csv', index_col=0)

    query_df.columns = ['image_path', 'label']

    query_df['image_path'] = query_df.image_path.map(lambda x : '/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data/query_images/' + x)

    item_mapping = {'1' : '54629736', '2' : '54481233', '3' : '3572171', '4' : '5558787', '5' : '4810550', '6' : '29566609', '7' : '100000000', '8':'4810554', '9' :'23296492','10':'22965966','11' :'100000010', '12' : '53798269', '13' : '100000001', '14':'5186005','15' :'23296489', '16':'38957303','17':'37989538', '18' :'5401467', '19' :'4385267', '20':'5142520','21':'53419173','22':'54747442','23':'53197162','24':'5262834','25':'54217299','26':'42430527','27':'6986914','28':'50563145','29':'100000003','30':'53564608','31':'100000004','32':'100000005','33':'100000006','34':'54271401','35':'100000007','36':'53621633','37':'53798262','38':'31525622','39':'53537941','40':'54739328','41':'52867343','42':'54003387','43':'54565142'}
    remove_lst = ['junk', '1', '7', '13', '29', '31', '32', '33', '35', '11']

    query_df = query_df[-query_df.label.isin(remove_lst)].reset_index(drop=True)

    query_df['label'] = query_df.label.map(lambda x : item_mapping[x])

    query_df['type'] = 'query'
    query_df['label_id'] = le.transform(query_df.label.values)

    query_df.head()

    data_train = '/'

    print(f'Test samples: {len(query_df)}.')

    # Making dataloaders
    def get_dl(df, folder, SZ=SZ, batch_size=256, augment='test', normalize='imagenet'):
        if data_type == 'normal':
            ds = GrocerImages_plus(folder, df, re_size=SZ, to_size=SZ,
                                 augment=augment, normalize=normalize, part=part, n_part=n_part)
        else:
            raise ValueError('invalid data type')
        dl = DataLoader(ds, batch_size=batch_size, shuffle=False, num_workers=8)
        return dl

    # 1. NORMAL RESULT
    # Make prototypes
    trn_dl = get_dl(proto_df, data_train)
    # model = feature_model
    model = get_model_fn(device=device, weight_file=weight_file)
    proto_net = ExtModelProtoNetClf(model, trn_dl.dataset.classes, device)
    proto_net.make_prototypes(trn_dl)

    data_test='/'

    # Calculate distances
    test_dl = get_dl(query_df, data_test, batch_size=256)
    test_embs, gts = proto_net.get_embeddings(test_dl)
    test_dists = proto_net.predict_embeddings(test_embs, softmax=False) #Distance are already negated so dist shub b high now

    from scipy.special import softmax
    test_probs = softmax(test_dists, axis=1)
    prototypes = np.array([x.mean() for x in proto_net.prototypes])

    (np.argsort(test_dists, axis=1)[:, :5] == np.argsort(test_probs, axis=1)[:, :5]).mean()

    top5labels = np.argsort(-test_dists, axis=1)[:, :5] #- is to sort in descending order

    top5preds = [test_dists[i][top5labels[i]] for i in range(test_dists.shape[0])]
    top5probs = [test_probs[i][top5labels[i]] for i in range(test_dists.shape[0])]

    top5probs = np.array(top5probs)
    top5preds = np.array(top5preds)

    query_df.columns

    query_df.columns = ['fpath', 'category', 'type', 'label_id']

    query_df['actual'] = query_df['category']

    for i in range(5):
        query_df[f'top_prob'+str(i+1)] = top5probs[:, i]

    for i in range(5):
        query_df[f'top_cat'+str(i+1)] = le.inverse_transform(top5labels[:, i])

    query_df['pred_cat'] = query_df['top_cat1']

    query_df['exp'] = exp

    query_df.head()

    query_df['fpath'] = query_df.fpath.map(lambda x : '/Users/r0b03m2/Desktop/Work/braincorp_data/query_images/' + Path(x).name)

    query_df['Flag'] = query_df.apply(lambda x: x['actual'] == x['pred_cat'], axis=1)

    query_df['Flag_top5'] = query_df.apply(lambda x: x['actual'] in x[['top_cat1', 'top_cat2', 'top_cat3', 'top_cat4', 'top_cat5']].values, axis=1)

    print(query_df.Flag.mean(), query_df.Flag_top5.mean())

    temp = query_df.groupby(['exp', 'category'])['Flag'].mean().reset_index()
    temp.columns = ['exp', 'category', 'accuracy']
    query_df = query_df.merge(temp, how='left', on=['exp', 'category'])

    temp = query_df.groupby(['exp', 'category'])['Flag_top5'].mean().reset_index()
    temp.columns = ['exp', 'category', 'accuracy_Top5']
    query_df = query_df.merge(temp, how='left', on=['exp', 'category'])

    query_df.head()

    # bc_proto_results = pd.DataFrame({'fpath':[str(i).replace('/home/raghava_balusu_walmartlabs_com/Work/oneshotml/data/braincorp_data', '/Users/r0b03m2/Desktop/Work/braincorp_data') for i in ref],
    #               'category' : [i.parent.name for i in ref],
    #               'exp': ['dummy' for i in range(len(ref))]})

    # bc_proto_results.head()

    result_df = pd.read_csv('results/bc_proto_results.csv')
    # result_df = bc_proto_results

    result_df.tail()

    # result_df.drop(result_df[result_df.exp == 'Grocer_res34_s1_q2_k80_epoch100'].index.values, inplace=True, axis=0)

    fin_df = result_df.append(query_df, ignore_index=True)

    fin_df.tail()

    fin_df.to_csv('results/bc_proto_results.csv', index=False)
# Out:
# Grocer_res34_s1_q2_k80_nonq7.6k_ref1.5k
# Test samples: 1676.
# 100%|██████████| 6/6 [00:06<00:00,  1.02s/it]
# 2020-04-22 19:01:36,473 dlcliche.utils make_prototypes [INFO]: Making new prototypes.
# 100%|██████████| 7/7 [00:05<00:00,  1.39it/s]
# 100%|██████████| 1676/1676 [00:17<00:00, 93.69it/s]
# 0.2022673031026253 0.3192124105011933
# Grocer_res34_s1_q2_k80_onlyref2.5k_ref1.5k
# Test samples: 1676.
# 100%|██████████| 6/6 [00:06<00:00,  1.08s/it]
# 2020-04-22 19:02:24,926 dlcliche.utils make_prototypes [INFO]: Making new prototypes.
# 100%|██████████| 7/7 [00:05<00:00,  1.40it/s]
# 100%|██████████| 1676/1676 [00:17<00:00, 93.59it/s]
# 0.19391408114558473 0.3383054892601432
# Grocer_res34_s1_q2_k80_onlyrefhard_ref1.5k
# Test samples: 1676.
# 100%|██████████| 6/6 [00:06<00:00,  1.03s/it]
# 2020-04-22 19:03:13,045 dlcliche.utils make_prototypes [INFO]: Making new prototypes.
# 100%|██████████| 7/7 [00:05<00:00,  1.41it/s]
# 100%|██████████| 1676/1676 [00:17<00:00, 94.63it/s]
# 0.20107398568019094 0.3168257756563246
# Grocer_res34_s1_q2_k80_onlyref_ref1.5k
# Test samples: 1676.
# 100%|██████████| 6/6 [00:06<00:00,  1.04s/it]
# 2020-04-22 19:04:01,085 dlcliche.utils make_prototypes [INFO]: Making new prototypes.
# 100%|██████████| 7/7 [00:05<00:00,  1.41it/s]
# 100%|██████████| 1676/1676 [00:17<00:00, 94.03it/s]
# 0.19033412887828163 0.26968973747016706
